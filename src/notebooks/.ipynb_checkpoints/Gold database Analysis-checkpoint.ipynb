# %%
# %reset -f

# %%
import pandas as pd
## We use a Factory object in the ontobio library
from ontobio import OntologyFactory
## We use the standard python networkx library for pathfinding here
## This is easily extracted from an ontology object
from networkx import nx

# %%
outputDir = '../../nlp/data/nlp/output/'
outFile = 'runNER_Output.tsv'
inputDir = '../../nlp/data/input/'
inFile = 'biosamples-expanded.tsv'
#cols = ['BiosampleId', 'Biolink', 'BeginTerm', 'EndTerm', 'TokenizedTerm', 'PreferredTerm', 'CURIE', 'NaN1', 'S-Type', 'NaN2', 'UMLS_CUI']
runnerOutput = pd.read_csv(outputDir+outFile, sep='\t' )
runnerOutput = runnerOutput.drop(['START POSITION', 'END POSITION', 'ZONE','SENTENCE ID', 'ORIGIN', 'UMLS CUI', 'SENTENCE'], axis = 1)
runnerOutput = runnerOutput.drop_duplicates()
print(len(runnerOutput))
runnerOutput.head()
# Out:
# 205959
#       DOCUMENT ID                       TYPE MATCHED TERM PREFERRED FORM  \
# 0  gold:Gb0101224      biolink:OntologyClass         Coal           coal
# 1  gold:Gb0101224      biolink:OntologyClass    Coal Mine      coal mine
# 4  gold:Gb0101224  biolink:ChemicalSubstance        water          water
# 5  gold:Gb0101224      biolink:OntologyClass        water   liquid water
# 6  gold:Gb0101225      biolink:OntologyClass         Coal           coal
#
#                ENTITY ID
# 0          ENVO:02000091
# 1          ENVO:00002169
# 4            CHEBI:15377
# 5  ENVO:00002006_SYNONYM
# 6          ENVO:02000091

# %%
# %%time
## Get the HPO using default method (currently OntoBee SPARQL)
## This may take 5-10s the first time you run it; afterwards it is cached
ofa = OntologyFactory()
ontology = ofa.create('envo')
## The OWL version of ENVO (used here) has many interesting relationship types;
## for now we just care about is-a (subClassOf between named classes)
ont = ontology.subontology(relations=['subClassOf', 'PART_OF'])
# Out:
# CPU times: user 3.67 s, sys: 57.4 ms, total: 3.73 s
# Wall time: 9.73 s

# %%
def getAncestors(entity):
    """
    Get all ancestors of entities
    """
    curieList = ont.search(entity)
    ancestorList = []
    for item in curieList:
        ancestorList.append(list(ont.ancestors(item)))
    
    return ancestorList

def getDescendants(entity):
    curieList = ont.search(entity)
    descendantList = []
    for item in curieList:
        descendantList.append(list(ont.descendants(item)))
    
    return descendantList

# %%
uniquePreferredTerms = runnerOutput['PREFERRED FORM'].unique()
uniquePreferredTermsDF = pd.DataFrame(uniquePreferredTerms, columns=['PREFERRED FORM'])
uniquePreferredTermsDF.head()
# Out:
#   PREFERRED FORM
# 0           coal
# 1      coal mine
# 2          water
# 3   liquid water
# 4         strait

# %%
# %%time
uniquePreferredTermsDF['Ancestors'] = uniquePreferredTermsDF.apply(lambda x: getAncestors(x['PREFERRED FORM']), axis=1)
uniquePreferredTermsDF['Descendants'] = uniquePreferredTermsDF.apply(lambda x: getDescendants(x['PREFERRED FORM']), axis=1)
print(len(uniquePreferredTermsDF))
uniquePreferredTermsDF.head()
# Out:
# 703
# CPU times: user 10.7 s, sys: 12.2 ms, total: 10.7 s
# Wall time: 10.7 s
#   PREFERRED FORM                                          Ancestors  \
# 0           coal  [[ENVO:00001995, ENVO:01000814, BFO:0000040, E...
# 1      coal mine  [[ENVO:01001813, ENVO:00000076, BFO:0000040, B...
# 2          water  [[CHEBI:33674, CHEBI:37577, BFO:0000001, BFO:0...
# 3   liquid water  [[ENVO:02000140, BFO:0000040, ENVO:00010483, B...
# 4         strait  [[ENVO:00000309, BFO:0000040, BFO:0000001, ENV...
#
#                                          Descendants
# 0  [[ENVO:2000044, ENVO:2000009, ENVO:2000008, EN...
# 1                                               [[]]
# 2                                               [[]]
# 3  [[ENVO:01000940, ENVO:01000358, ENVO:00005791,...
# 4                                  [[ENVO:01000651]]

# %%
runnerOutputWithAncestors = runnerOutput.merge(uniquePreferredTermsDF, on='PREFERRED FORM', how='left' )
print(len(runnerOutputWithAncestors))
runnerOutputWithAncestors.head()
# Out:
# 205959
#       DOCUMENT ID                       TYPE MATCHED TERM PREFERRED FORM  \
# 0  gold:Gb0101224      biolink:OntologyClass         Coal           coal
# 1  gold:Gb0101224      biolink:OntologyClass    Coal Mine      coal mine
# 2  gold:Gb0101224  biolink:ChemicalSubstance        water          water
# 3  gold:Gb0101224      biolink:OntologyClass        water   liquid water
# 4  gold:Gb0101225      biolink:OntologyClass         Coal           coal
#
#                ENTITY ID                                          Ancestors  \
# 0          ENVO:02000091  [[ENVO:00001995, ENVO:01000814, BFO:0000040, E...
# 1          ENVO:00002169  [[ENVO:01001813, ENVO:00000076, BFO:0000040, B...
# 2            CHEBI:15377  [[CHEBI:33674, CHEBI:37577, BFO:0000001, BFO:0...
# 3  ENVO:00002006_SYNONYM  [[ENVO:02000140, BFO:0000040, ENVO:00010483, B...
# 4          ENVO:02000091  [[ENVO:00001995, ENVO:01000814, BFO:0000040, E...
#
#                                          Descendants
# 0  [[ENVO:2000044, ENVO:2000009, ENVO:2000008, EN...
# 1                                               [[]]
# 2                                               [[]]
# 3  [[ENVO:01000940, ENVO:01000358, ENVO:00005791,...
# 4  [[ENVO:2000044, ENVO:2000009, ENVO:2000008, EN...

# %%
goldInput = pd.read_csv(inputDir+inFile, sep='\t', low_memory=False, usecols=['id', 'env_broad_scale', 'env_local_scale', 'env_medium'] )
#goldInput['id'] = goldInput['id'].str.strip('gold:')
goldInput.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium
# 0  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 1  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 2  gold:Gb0101226   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 3  gold:Gb0101227   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 4  gold:Gb0101253   ENVO:00000446   ENVO:00002185  ENVO:00002985

# %%
inputOutputJoin = goldInput.merge(runnerOutput, left_on='id', right_on='DOCUMENT ID', how='left' )
inputOutputJoin.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 1  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 2  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 3  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 4  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
#
#       DOCUMENT ID                       TYPE MATCHED TERM PREFERRED FORM  \
# 0  gold:Gb0101224      biolink:OntologyClass         Coal           coal
# 1  gold:Gb0101224      biolink:OntologyClass    Coal Mine      coal mine
# 2  gold:Gb0101224  biolink:ChemicalSubstance        water          water
# 3  gold:Gb0101224      biolink:OntologyClass        water   liquid water
# 4  gold:Gb0101225      biolink:OntologyClass         Coal           coal
#
#                ENTITY ID
# 0          ENVO:02000091
# 1          ENVO:00002169
# 2            CHEBI:15377
# 3  ENVO:00002006_SYNONYM
# 4          ENVO:02000091

# %%
inputOutputJoin = inputOutputJoin.drop(['DOCUMENT ID'], axis=1)
#inputOutputJoin = inputOutputJoin.drop_duplicates()
inputOutputJoin['CURIE'] = inputOutputJoin['ENTITY ID'].str.strip('_SYNONYM')
inputOutputJoin = inputOutputJoin.drop(['ENTITY ID'], axis=1)
inputOutputJoin.head(10)
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 1  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 2  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 3  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 4  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 5  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 6  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 7  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 8  gold:Gb0101226   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 9  gold:Gb0101226   ENVO:00002030   ENVO:00002169  ENVO:00005792
#
#                         TYPE MATCHED TERM PREFERRED FORM          CURIE
# 0      biolink:OntologyClass         Coal           coal  ENVO:02000091
# 1      biolink:OntologyClass    Coal Mine      coal mine  ENVO:00002169
# 2  biolink:ChemicalSubstance        water          water    CHEBI:15377
# 3      biolink:OntologyClass        water   liquid water  ENVO:00002006
# 4      biolink:OntologyClass         Coal           coal  ENVO:02000091
# 5      biolink:OntologyClass    Coal Mine      coal mine  ENVO:00002169
# 6  biolink:ChemicalSubstance        water          water    CHEBI:15377
# 7      biolink:OntologyClass        water   liquid water  ENVO:00002006
# 8      biolink:OntologyClass         Coal           coal  ENVO:02000091
# 9      biolink:OntologyClass    Coal Mine      coal mine  ENVO:00002169

# %%
inputOutputJoin.to_csv(outputDir+'inputOutputJoined.tsv', sep='\t', index=None)

# %%
filteredMatch = inputOutputJoin.query('CURIE == env_broad_scale' and \
                                      'CURIE == env_local_scale' and \
                                      'CURIE == env_medium')

#filteredMatch = filteredMatch.drop_duplicates()

# %%
filteredMatch.head()
# Out:
#                   id env_broad_scale env_local_scale     env_medium  \
# 17    gold:Gb0101253   ENVO:00000446   ENVO:00002185  ENVO:00002985
# 24    gold:Gb0101254   ENVO:00000446   ENVO:00002185  ENVO:00002985
# 1454  gold:Gb0102398   ENVO:00000447   ENVO:00000208  ENVO:03000033
# 1460  gold:Gb0102399   ENVO:00000447   ENVO:00000208  ENVO:03000033
# 1466  gold:Gb0102400   ENVO:00000447   ENVO:00000208  ENVO:03000033
#
#                        TYPE     MATCHED TERM   PREFERRED FORM          CURIE
# 17    biolink:OntologyClass              oil              oil  ENVO:00002985
# 24    biolink:OntologyClass              oil              oil  ENVO:00002985
# 1454  biolink:OntologyClass  marine sediment  marine sediment  ENVO:03000033
# 1460  biolink:OntologyClass  marine sediment  marine sediment  ENVO:03000033
# 1466  biolink:OntologyClass  marine sediment  marine sediment  ENVO:03000033

# %%
filteredMatch.to_csv(outputDir+'filteredMatch.tsv', sep='\t', index=None)

# %%
len(inputOutputJoin)
# Out:
# 208131

# %%
# env_{local,medium,broad}_matched
inputOutputJoin['env_broad_matched'] = inputOutputJoin['CURIE'] == inputOutputJoin['env_broad_scale']
inputOutputJoin['env_local_matched'] = inputOutputJoin['CURIE'] == inputOutputJoin['env_local_scale']
inputOutputJoin['env_medium_matched'] = inputOutputJoin['CURIE'] == inputOutputJoin['env_medium']
inputOutputJoin['false_positives'] = (inputOutputJoin.iloc[:,-3:]==False).all(True)

inputOutputJoin.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 1  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 2  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 3  gold:Gb0101224   ENVO:00002030   ENVO:00002169  ENVO:00005792
# 4  gold:Gb0101225   ENVO:00002030   ENVO:00002169  ENVO:00005792
#
#                         TYPE MATCHED TERM PREFERRED FORM          CURIE  \
# 0      biolink:OntologyClass         Coal           coal  ENVO:02000091
# 1      biolink:OntologyClass    Coal Mine      coal mine  ENVO:00002169
# 2  biolink:ChemicalSubstance        water          water    CHEBI:15377
# 3      biolink:OntologyClass        water   liquid water  ENVO:00002006
# 4      biolink:OntologyClass         Coal           coal  ENVO:02000091
#
#    env_broad_matched  env_local_matched  env_medium_matched  false_positives
# 0              False              False               False             True
# 1              False               True               False            False
# 2              False              False               False             True
# 3              False              False               False             True
# 4              False              False               False             True

# %%
grpList = ['id', 'env_broad_scale', 'env_local_scale', 'env_medium', 'TYPE', 'MATCHED TERM', 'PREFERRED FORM', 'CURIE']

collapsedIO  = inputOutputJoin.groupby(grpList).any()

# %%
collapsedIO.head()
# Out:
#                                                                                                                               env_broad_matched  \
# id             env_broad_scale env_local_scale env_medium    TYPE                  MATCHED TERM PREFERRED FORM CURIE
# gold:Gb0050971 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998              False
#                                                                                    ecosystem    ecosystem      ENVO:01001110              False
# gold:Gb0050972 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998              False
#                                                                                    ecosystem    ecosystem      ENVO:01001110              False
# gold:Gb0050973 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998              False
#
#                                                                                                                               env_local_matched  \
# id             env_broad_scale env_local_scale env_medium    TYPE                  MATCHED TERM PREFERRED FORM CURIE
# gold:Gb0050971 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998              False
#                                                                                    ecosystem    ecosystem      ENVO:01001110              False
# gold:Gb0050972 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998              False
#                                                                                    ecosystem    ecosystem      ENVO:01001110              False
# gold:Gb0050973 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998              False
#
#                                                                                                                               env_medium_matched  \
# id             env_broad_scale env_local_scale env_medium    TYPE                  MATCHED TERM PREFERRED FORM CURIE
# gold:Gb0050971 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998                True
#                                                                                    ecosystem    ecosystem      ENVO:01001110               False
# gold:Gb0050972 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998                True
#                                                                                    ecosystem    ecosystem      ENVO:01001110               False
# gold:Gb0050973 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998                True
#
#                                                                                                                               false_positives
# id             env_broad_scale env_local_scale env_medium    TYPE                  MATCHED TERM PREFERRED FORM CURIE
# gold:Gb0050971 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998            False
#                                                                                    ecosystem    ecosystem      ENVO:01001110             True
# gold:Gb0050972 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998            False
#                                                                                    ecosystem    ecosystem      ENVO:01001110             True
# gold:Gb0050973 ENVO:00000446   ENVO:01001785   ENVO:00001998 biolink:OntologyClass Soil         soil           ENVO:00001998            False

# %%
collapsedIO.to_csv(outputDir+'inputOutputComparison.tsv', sep='\t')

# %%
len(collapsedIO)
# Out:
# 169239

# %%
newDf = pd.read_csv(outputDir+'inputOutputComparison.tsv', sep='\t', low_memory=False)
newDf.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 1  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 2  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 3  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 4  gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
#
#                     TYPE MATCHED TERM PREFERRED FORM          CURIE  \
# 0  biolink:OntologyClass         Soil           soil  ENVO:00001998
# 1  biolink:OntologyClass    ecosystem      ecosystem  ENVO:01001110
# 2  biolink:OntologyClass         Soil           soil  ENVO:00001998
# 3  biolink:OntologyClass    ecosystem      ecosystem  ENVO:01001110
# 4  biolink:OntologyClass         Soil           soil  ENVO:00001998
#
#    env_broad_matched  env_local_matched  env_medium_matched  false_positives
# 0              False              False                True            False
# 1              False              False               False             True
# 2              False              False                True            False
# 3              False              False               False             True
# 4              False              False                True            False

# %%
newDf = newDf.merge(uniquePreferredTermsDF, on='PREFERRED FORM', how='left' )
newDf.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 1  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 2  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 3  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 4  gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
#
#                     TYPE MATCHED TERM PREFERRED FORM          CURIE  \
# 0  biolink:OntologyClass         Soil           soil  ENVO:00001998
# 1  biolink:OntologyClass    ecosystem      ecosystem  ENVO:01001110
# 2  biolink:OntologyClass         Soil           soil  ENVO:00001998
# 3  biolink:OntologyClass    ecosystem      ecosystem  ENVO:01001110
# 4  biolink:OntologyClass         Soil           soil  ENVO:00001998
#
#    env_broad_matched  env_local_matched  env_medium_matched  false_positives  \
# 0              False              False                True            False
# 1              False              False               False             True
# 2              False              False                True            False
# 3              False              False               False             True
# 4              False              False                True            False
#
#                                            Ancestors  \
# 0  [[BFO:0000040, ENVO:00010483, BFO:0000001, BFO...
# 1  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 2  [[BFO:0000040, ENVO:00010483, BFO:0000001, BFO...
# 3  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 4  [[BFO:0000040, ENVO:00010483, BFO:0000001, BFO...
#
#                                          Descendants
# 0  [[ENVO:00005752, ENVO:00003082, ENVO:00002230,...
# 1  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...
# 2  [[ENVO:00005752, ENVO:00003082, ENVO:00002230,...
# 3  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...
# 4  [[ENVO:00005752, ENVO:00003082, ENVO:00002230,...

# %%
newDf.to_csv(outputDir+'inputOutputComparisonWithAncesAndDesc.tsv', sep='\t', index=None)

# %%
def checkParentAndDescendant(row, idx):
    #x.env_broad_scale in x.Ancestors[idx]
    if idx == 0:
        if row.env_broad_matched == True:
            return 'ExactMatch'
        else:
            ancestor = row.env_broad_scale in row.Ancestors[0]
            descendant = row.env_broad_scale in row.Descendants[0]
    elif idx == 1:
        if row.env_local_matched == True:
            return 'ExactMatch'
        else:
            ancestor = row.env_local_scale in row.Ancestors[0]
            descendant = row.env_local_scale in row.Descendants[0]
    elif idx == 2:
        if row.env_medium_matched == True:
            return 'ExactMatch'
        else:
            ancestor = row.env_medium in row.Ancestors[0]
            descendant = row.env_medium in row.Descendants[0]
        
    if ancestor:
        return 'AncestorMatch'
    elif descendant:
        return 'DescendantMatch'
    else:
        return 'NoMatch'

# %%
# %%time
newDf.loc[:,'env_broad_match_type'] = newDf.apply(lambda x:checkParentAndDescendant(x,0) , axis=1)
newDf.loc[:,'env_local_match_type'] = newDf.apply(lambda x:checkParentAndDescendant(x,1) , axis=1)
newDf.loc[:,'env_medium_match_type'] = newDf.apply(lambda x:checkParentAndDescendant(x,2) , axis=1)
newDf.to_csv(outputDir+'inputOutputWithMatches.tsv', sep='\t', index=None)
newDf.head()
# Out:
# CPU times: user 16.4 s, sys: 132 ms, total: 16.6 s
# Wall time: 16.6 s
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 1  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 2  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 3  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 4  gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
#
#                     TYPE MATCHED TERM PREFERRED FORM          CURIE  \
# 0  biolink:OntologyClass         Soil           soil  ENVO:00001998
# 1  biolink:OntologyClass    ecosystem      ecosystem  ENVO:01001110
# 2  biolink:OntologyClass         Soil           soil  ENVO:00001998
# 3  biolink:OntologyClass    ecosystem      ecosystem  ENVO:01001110
# 4  biolink:OntologyClass         Soil           soil  ENVO:00001998
#
#    env_broad_matched  env_local_matched  env_medium_matched  false_positives  \
# 0              False              False                True            False
# 1              False              False               False             True
# 2              False              False                True            False
# 3              False              False               False             True
# 4              False              False                True            False
#
#                                            Ancestors  \
# 0  [[BFO:0000040, ENVO:00010483, BFO:0000001, BFO...
# 1  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 2  [[BFO:0000040, ENVO:00010483, BFO:0000001, BFO...
# 3  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 4  [[BFO:0000040, ENVO:00010483, BFO:0000001, BFO...
#
#                                          Descendants env_broad_match_type  \
# 0  [[ENVO:00005752, ENVO:00003082, ENVO:00002230,...              NoMatch
# 1  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...      DescendantMatch
# 2  [[ENVO:00005752, ENVO:00003082, ENVO:00002230,...              NoMatch
# 3  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...      DescendantMatch
# 4  [[ENVO:00005752, ENVO:00003082, ENVO:00002230,...              NoMatch
#
#   env_local_match_type env_medium_match_type
# 0              NoMatch            ExactMatch
# 1              NoMatch               NoMatch
# 2              NoMatch            ExactMatch
# 3              NoMatch               NoMatch
# 4              NoMatch            ExactMatch

# %%
def removeDupsInCell(df, col):
    df[col] = df[col].str.split(',').apply(set).str.join(',')
    return df

# %%
consolidatedDF = newDf.groupby(['id'])\
                        .agg({
                                'env_broad_scale': lambda a: ','.join(a),
                                'env_local_scale': lambda b: ','.join(b),
                                'env_medium': lambda c: ','.join(c),
                                'TYPE': lambda d: ','.join(d),
                                'MATCHED TERM': lambda e: ','.join(e),
                                'PREFERRED FORM': lambda f: ','.join(f),
                                'CURIE': lambda g: ','.join(g),
                                'env_broad_matched': lambda h: ','.join(str(v).upper() for v in h),
                                'env_local_matched': lambda i: ','.join(str(x).upper() for x in i),
                                'env_medium_matched': lambda j: ','.join(str(y).upper() for y in j),
                                'env_broad_match_type': lambda h: ','.join(v for v in h),
                                'env_local_match_type': lambda i: ','.join(x for x in i),
                                'env_medium_match_type': lambda j: ','.join(y for y in j),
                                'false_positives': lambda k: ','.join(str(z).upper() for z in k),
                                'Ancestors': lambda l: '|'.join(str(u) for u in l),
                                'Descendants': lambda m: '|'.join(str(t) for t in m)
                            })
consolidatedDF.head()
# Out:
#                                                   env_broad_scale  \
# id
# gold:Gb0050971                        ENVO:00000446,ENVO:00000446
# gold:Gb0050972                        ENVO:00000446,ENVO:00000446
# gold:Gb0050973                        ENVO:00000446,ENVO:00000446
# gold:Gb0050974                        ENVO:00000446,ENVO:00000446
# gold:Gb0050975  ENVO:00002030,ENVO:00002030,ENVO:00002030,ENVO...
#
#                                                   env_local_scale  \
# id
# gold:Gb0050971                        ENVO:01001785,ENVO:01001785
# gold:Gb0050972                        ENVO:01001785,ENVO:01001785
# gold:Gb0050973                        ENVO:01001785,ENVO:01001785
# gold:Gb0050974                        ENVO:01001785,ENVO:01001785
# gold:Gb0050975  ENVO:00001997,ENVO:00001997,ENVO:00001997,ENVO...
#
#                                                        env_medium  \
# id
# gold:Gb0050971                        ENVO:00001998,ENVO:00001998
# gold:Gb0050972                        ENVO:00001998,ENVO:00001998
# gold:Gb0050973                        ENVO:00001998,ENVO:00001998
# gold:Gb0050974                        ENVO:00001998,ENVO:00001998
# gold:Gb0050975  ENVO:00002034,ENVO:00002034,ENVO:00002034,ENVO...
#
#                                                              TYPE  \
# id
# gold:Gb0050971        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050972        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050973        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050974        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050975  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                                      MATCHED TERM  \
# id
# gold:Gb0050971                                     Soil,ecosystem
# gold:Gb0050972                                     Soil,ecosystem
# gold:Gb0050973                                     Soil,ecosystem
# gold:Gb0050974                                     Soil,ecosystem
# gold:Gb0050975  Acid,Acid Mine Drainage,Biofilm,Mine Drainage,...
#
#                                                    PREFERRED FORM  \
# id
# gold:Gb0050971                                     soil,ecosystem
# gold:Gb0050972                                     soil,ecosystem
# gold:Gb0050973                                     soil,ecosystem
# gold:Gb0050974                                     soil,ecosystem
# gold:Gb0050975  acid,acid mine drainage,biofilm,mine drainage,...
#
#                                                             CURIE  \
# id
# gold:Gb0050971                        ENVO:00001998,ENVO:01001110
# gold:Gb0050972                        ENVO:00001998,ENVO:01001110
# gold:Gb0050973                        ENVO:00001998,ENVO:01001110
# gold:Gb0050974                        ENVO:00001998,ENVO:01001110
# gold:Gb0050975  CHEBI:37527,ENVO:00001997,ENVO:00002034,ENVO:0...
#
#                                                 env_broad_matched  \
# id
# gold:Gb0050971                                        FALSE,FALSE
# gold:Gb0050972                                        FALSE,FALSE
# gold:Gb0050973                                        FALSE,FALSE
# gold:Gb0050974                                        FALSE,FALSE
# gold:Gb0050975  FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALS...
#
#                                                 env_local_matched  \
# id
# gold:Gb0050971                                        FALSE,FALSE
# gold:Gb0050972                                        FALSE,FALSE
# gold:Gb0050973                                        FALSE,FALSE
# gold:Gb0050974                                        FALSE,FALSE
# gold:Gb0050975  FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                                env_medium_matched  \
# id
# gold:Gb0050971                                         TRUE,FALSE
# gold:Gb0050972                                         TRUE,FALSE
# gold:Gb0050973                                         TRUE,FALSE
# gold:Gb0050974                                         TRUE,FALSE
# gold:Gb0050975  FALSE,FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                              env_broad_match_type  \
# id
# gold:Gb0050971                            NoMatch,DescendantMatch
# gold:Gb0050972                            NoMatch,DescendantMatch
# gold:Gb0050973                            NoMatch,DescendantMatch
# gold:Gb0050974                            NoMatch,DescendantMatch
# gold:Gb0050975  NoMatch,NoMatch,NoMatch,NoMatch,NoMatch,NoMatc...
#
#                                              env_local_match_type  \
# id
# gold:Gb0050971                                    NoMatch,NoMatch
# gold:Gb0050972                                    NoMatch,NoMatch
# gold:Gb0050973                                    NoMatch,NoMatch
# gold:Gb0050974                                    NoMatch,NoMatch
# gold:Gb0050975  NoMatch,ExactMatch,NoMatch,DescendantMatch,NoM...
#
#                                             env_medium_match_type  \
# id
# gold:Gb0050971                                 ExactMatch,NoMatch
# gold:Gb0050972                                 ExactMatch,NoMatch
# gold:Gb0050973                                 ExactMatch,NoMatch
# gold:Gb0050974                                 ExactMatch,NoMatch
# gold:Gb0050975  NoMatch,NoMatch,ExactMatch,NoMatch,NoMatch,NoM...
#
#                                                false_positives  \
# id
# gold:Gb0050971                                      FALSE,TRUE
# gold:Gb0050972                                      FALSE,TRUE
# gold:Gb0050973                                      FALSE,TRUE
# gold:Gb0050974                                      FALSE,TRUE
# gold:Gb0050975  TRUE,FALSE,FALSE,TRUE,TRUE,TRUE,TRUE,TRUE,TRUE
#
#                                                         Ancestors  \
# id
# gold:Gb0050971  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050972  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050973  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050974  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050975  [['CHEBI:51086', 'CHEBI:50906']]|[['ENVO:00000...
#
#                                                       Descendants
# id
# gold:Gb0050971  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050972  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050973  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050974  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050975  [['CHEBI:39143', 'CHEBI:48356', 'CHEBI:48360',...

# %%
consolidatedDF = removeDupsInCell(consolidatedDF, 'env_broad_scale')
consolidatedDF = removeDupsInCell(consolidatedDF, 'env_local_scale')
consolidatedDF = removeDupsInCell(consolidatedDF, 'env_medium')

consolidatedDF.head()
# Out:
#                env_broad_scale env_local_scale     env_medium  \
# id
# gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
# gold:Gb0050974   ENVO:00000446   ENVO:01001785  ENVO:00001998
# gold:Gb0050975   ENVO:00002030   ENVO:00001997  ENVO:00002034
#
#                                                              TYPE  \
# id
# gold:Gb0050971        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050972        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050973        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050974        biolink:OntologyClass,biolink:OntologyClass
# gold:Gb0050975  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                                      MATCHED TERM  \
# id
# gold:Gb0050971                                     Soil,ecosystem
# gold:Gb0050972                                     Soil,ecosystem
# gold:Gb0050973                                     Soil,ecosystem
# gold:Gb0050974                                     Soil,ecosystem
# gold:Gb0050975  Acid,Acid Mine Drainage,Biofilm,Mine Drainage,...
#
#                                                    PREFERRED FORM  \
# id
# gold:Gb0050971                                     soil,ecosystem
# gold:Gb0050972                                     soil,ecosystem
# gold:Gb0050973                                     soil,ecosystem
# gold:Gb0050974                                     soil,ecosystem
# gold:Gb0050975  acid,acid mine drainage,biofilm,mine drainage,...
#
#                                                             CURIE  \
# id
# gold:Gb0050971                        ENVO:00001998,ENVO:01001110
# gold:Gb0050972                        ENVO:00001998,ENVO:01001110
# gold:Gb0050973                        ENVO:00001998,ENVO:01001110
# gold:Gb0050974                        ENVO:00001998,ENVO:01001110
# gold:Gb0050975  CHEBI:37527,ENVO:00001997,ENVO:00002034,ENVO:0...
#
#                                                 env_broad_matched  \
# id
# gold:Gb0050971                                        FALSE,FALSE
# gold:Gb0050972                                        FALSE,FALSE
# gold:Gb0050973                                        FALSE,FALSE
# gold:Gb0050974                                        FALSE,FALSE
# gold:Gb0050975  FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALS...
#
#                                                 env_local_matched  \
# id
# gold:Gb0050971                                        FALSE,FALSE
# gold:Gb0050972                                        FALSE,FALSE
# gold:Gb0050973                                        FALSE,FALSE
# gold:Gb0050974                                        FALSE,FALSE
# gold:Gb0050975  FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                                env_medium_matched  \
# id
# gold:Gb0050971                                         TRUE,FALSE
# gold:Gb0050972                                         TRUE,FALSE
# gold:Gb0050973                                         TRUE,FALSE
# gold:Gb0050974                                         TRUE,FALSE
# gold:Gb0050975  FALSE,FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                              env_broad_match_type  \
# id
# gold:Gb0050971                            NoMatch,DescendantMatch
# gold:Gb0050972                            NoMatch,DescendantMatch
# gold:Gb0050973                            NoMatch,DescendantMatch
# gold:Gb0050974                            NoMatch,DescendantMatch
# gold:Gb0050975  NoMatch,NoMatch,NoMatch,NoMatch,NoMatch,NoMatc...
#
#                                              env_local_match_type  \
# id
# gold:Gb0050971                                    NoMatch,NoMatch
# gold:Gb0050972                                    NoMatch,NoMatch
# gold:Gb0050973                                    NoMatch,NoMatch
# gold:Gb0050974                                    NoMatch,NoMatch
# gold:Gb0050975  NoMatch,ExactMatch,NoMatch,DescendantMatch,NoM...
#
#                                             env_medium_match_type  \
# id
# gold:Gb0050971                                 ExactMatch,NoMatch
# gold:Gb0050972                                 ExactMatch,NoMatch
# gold:Gb0050973                                 ExactMatch,NoMatch
# gold:Gb0050974                                 ExactMatch,NoMatch
# gold:Gb0050975  NoMatch,NoMatch,ExactMatch,NoMatch,NoMatch,NoM...
#
#                                                false_positives  \
# id
# gold:Gb0050971                                      FALSE,TRUE
# gold:Gb0050972                                      FALSE,TRUE
# gold:Gb0050973                                      FALSE,TRUE
# gold:Gb0050974                                      FALSE,TRUE
# gold:Gb0050975  TRUE,FALSE,FALSE,TRUE,TRUE,TRUE,TRUE,TRUE,TRUE
#
#                                                         Ancestors  \
# id
# gold:Gb0050971  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050972  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050973  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050974  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# gold:Gb0050975  [['CHEBI:51086', 'CHEBI:50906']]|[['ENVO:00000...
#
#                                                       Descendants
# id
# gold:Gb0050971  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050972  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050973  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050974  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# gold:Gb0050975  [['CHEBI:39143', 'CHEBI:48356', 'CHEBI:48360',...

# %%
consolidatedDF.to_csv(outputDir+'AllGroupedById.tsv', sep='\t')

# %%
newDfSelect = newDf[['id','MATCHED TERM','TYPE', 'PREFERRED FORM', 'CURIE', 'false_positives', 'env_broad_match_type', 'env_local_match_type', 'env_medium_match_type', 'Ancestors', 'Descendants']]
falsePosSubset = newDfSelect[newDfSelect['false_positives'] == True]
falsePosSubset.head()
# Out:
#                id MATCHED TERM                       TYPE PREFERRED FORM  \
# 1  gold:Gb0050971    ecosystem      biolink:OntologyClass      ecosystem
# 3  gold:Gb0050972    ecosystem      biolink:OntologyClass      ecosystem
# 5  gold:Gb0050973    ecosystem      biolink:OntologyClass      ecosystem
# 7  gold:Gb0050974    ecosystem      biolink:OntologyClass      ecosystem
# 8  gold:Gb0050975         Acid  biolink:ChemicalSubstance           acid
#
#            CURIE  false_positives env_broad_match_type env_local_match_type  \
# 1  ENVO:01001110             True      DescendantMatch              NoMatch
# 3  ENVO:01001110             True      DescendantMatch              NoMatch
# 5  ENVO:01001110             True      DescendantMatch              NoMatch
# 7  ENVO:01001110             True      DescendantMatch              NoMatch
# 8    CHEBI:37527             True              NoMatch              NoMatch
#
#   env_medium_match_type                                          Ancestors  \
# 1               NoMatch  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 3               NoMatch  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 5               NoMatch  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 7               NoMatch  [[RO:0002577, ENVO:01000254, BFO:0000040, BFO:...
# 8               NoMatch                       [[CHEBI:51086, CHEBI:50906]]
#
#                                          Descendants
# 1  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...
# 3  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...
# 5  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...
# 7  [[ENVO:01001452, ENVO:00000447, ENVO:00000192,...
# 8  [[CHEBI:39143, CHEBI:48356, CHEBI:48360, CHEBI...

# %%
len(falsePosSubset)
# Out:
# 146315

# %%
consolidatedFalseCURIEs = falsePosSubset.groupby(['id'])\
                        .agg({
                                'CURIE': lambda x: ','.join(x),
                                'TYPE': lambda a: ','.join(a),
                                'MATCHED TERM': lambda y: ','.join(y),
                                'PREFERRED FORM': lambda z: ','.join(z)
                            })\
                        .rename(columns={'CURIE':'falsePositiveCURIEs'})
consolidatedFalseCURIEs.head(10)
# Out:
#                                               falsePositiveCURIEs  \
# id
# gold:Gb0050971                                      ENVO:01001110
# gold:Gb0050972                                      ENVO:01001110
# gold:Gb0050973                                      ENVO:01001110
# gold:Gb0050974                                      ENVO:01001110
# gold:Gb0050975  CHEBI:37527,ENVO:00001996,ENVO:00000083,ENVO:0...
# gold:Gb0050977                                      ENVO:00000015
# gold:Gb0050978          ENVO:01001788,ENVO:00000015,ENVO:01001110
# gold:Gb0050979  ENVO:00000165,ENVO:00002277,ENVO:00000291,ENVO...
# gold:Gb0050980  UBERON:0001474,UBERON:0002481,ENVO:00000165,EN...
# gold:Gb0050981  UBERON:0001474,UBERON:0002481,ENVO:00000040,EN...
#
#                                                              TYPE  \
# id
# gold:Gb0050971                              biolink:OntologyClass
# gold:Gb0050972                              biolink:OntologyClass
# gold:Gb0050973                              biolink:OntologyClass
# gold:Gb0050974                              biolink:OntologyClass
# gold:Gb0050975  biolink:ChemicalSubstance,biolink:OntologyClas...
# gold:Gb0050977                              biolink:OntologyClass
# gold:Gb0050978  biolink:OntologyClass,biolink:OntologyClass,bi...
# gold:Gb0050979  biolink:OntologyClass,biolink:OntologyClass,bi...
# gold:Gb0050980  biolink:AnatomicalEntity,biolink:AnatomicalEnt...
# gold:Gb0050981  biolink:AnatomicalEntity,biolink:AnatomicalEnt...
#
#                                                      MATCHED TERM  \
# id
# gold:Gb0050971                                          ecosystem
# gold:Gb0050972                                          ecosystem
# gold:Gb0050973                                          ecosystem
# gold:Gb0050974                                          ecosystem
# gold:Gb0050975  Acid,Mine Drainage,Mountain,Mountain,Mountain,...
# gold:Gb0050977                                              Ocean
# gold:Gb0050978                   Marine ecosystem,Ocean,ecosystem
# gold:Gb0050979  Basin,Basin,Basin,Basin,Basin,Basin,Basin,Fall...
# gold:Gb0050980  Bone,Bone,Basin,Basin,Basin,Basin,Basin,Basin,...
# gold:Gb0050981  Bone,Bone,Fall,Peninsula,West,Whale Fall,micro...
#
#                                                    PREFERRED FORM
# id
# gold:Gb0050971                                          ecosystem
# gold:Gb0050972                                          ecosystem
# gold:Gb0050973                                          ecosystem
# gold:Gb0050974                                          ecosystem
# gold:Gb0050975  acid,mine drainage,hill,mount,mountain,seamoun...
# gold:Gb0050977                                              ocean
# gold:Gb0050978                   marine ecosystem,ocean,ecosystem
# gold:Gb0050979  asphalt lake,back-arc basin,drainage basin,ket...
# gold:Gb0050980  bone element,bone tissue,asphalt lake,back-arc...
# gold:Gb0050981  bone element,bone tissue,waterfall,peninsula,w...

# %%
consolidatedFalseCURIEs.to_csv(outputDir+'falsePositivesGroupedById.tsv', sep='\t')

# %%
falsePositives = pd.read_csv(outputDir+'falsePositivesGroupedById.tsv', sep='\t', low_memory=False)
falsePositives['false_positives'] = True
falsePositives.head()
# Out:
#                id                                falsePositiveCURIEs  \
# 0  gold:Gb0050971                                      ENVO:01001110
# 1  gold:Gb0050972                                      ENVO:01001110
# 2  gold:Gb0050973                                      ENVO:01001110
# 3  gold:Gb0050974                                      ENVO:01001110
# 4  gold:Gb0050975  CHEBI:37527,ENVO:00001996,ENVO:00000083,ENVO:0...
#
#                                                 TYPE  \
# 0                              biolink:OntologyClass
# 1                              biolink:OntologyClass
# 2                              biolink:OntologyClass
# 3                              biolink:OntologyClass
# 4  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                         MATCHED TERM  \
# 0                                          ecosystem
# 1                                          ecosystem
# 2                                          ecosystem
# 3                                          ecosystem
# 4  Acid,Mine Drainage,Mountain,Mountain,Mountain,...
#
#                                       PREFERRED FORM  false_positives
# 0                                          ecosystem             True
# 1                                          ecosystem             True
# 2                                          ecosystem             True
# 3                                          ecosystem             True
# 4  acid,mine drainage,hill,mount,mountain,seamoun...             True

# %%
newDf = newDf.drop(['CURIE', 'TYPE', 'MATCHED TERM', 'PREFERRED FORM'], axis=1)
finalDF = newDf.merge(falsePositives, on=['id', 'false_positives'],how='left')

# %%
goldInput = pd.read_csv('../../nlp/data/nlp/input/nlpGOLDInput.tsv', sep='\t', low_memory=False, index_col=None)
goldInput.head()
# Out:
#                id                                               text
# 0  gold:Gb0101224  Lithgow State Coal Mine Calcium nutrients (ear...
# 1  gold:Gb0101225  Lithgow State Coal Mine Calcium nutrients Extr...
# 2  gold:Gb0101226  Lithgow State Coal Mine Calcium nutrients. Lit...
# 3  gold:Gb0101227  Lithgow State Coal Mine Calcium merged assembl...
# 4  gold:Gb0101253  Bass Strait oil field metagenomics - A7A-2. Ba...

# %%
finalDF.to_csv(outputDir+'finalOutput.tsv', sep='\t', index=None)

# %%
onlyFalsePosivitesDF = newDf[newDf['false_positives'] == True].merge(falsePositives, on='id',how='inner')
onlyFalsePosivitesDF = onlyFalsePosivitesDF.drop(['false_positives_x', 'false_positives_y', 'Ancestors', 'Descendants'], axis=1)
onlyFalsePosivitesDF = onlyFalsePosivitesDF.drop_duplicates()
print(len(onlyFalsePosivitesDF))
onlyFalsePosivitesDF.head()
# Out:
# 41725
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 1  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 2  gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 3  gold:Gb0050974   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 4  gold:Gb0050975   ENVO:00002030   ENVO:00001997  ENVO:00002034
#
#    env_broad_matched  env_local_matched  env_medium_matched  \
# 0              False              False               False
# 1              False              False               False
# 2              False              False               False
# 3              False              False               False
# 4              False              False               False
#
#   env_broad_match_type env_local_match_type env_medium_match_type  \
# 0      DescendantMatch              NoMatch               NoMatch
# 1      DescendantMatch              NoMatch               NoMatch
# 2      DescendantMatch              NoMatch               NoMatch
# 3      DescendantMatch              NoMatch               NoMatch
# 4              NoMatch              NoMatch               NoMatch
#
#                                  falsePositiveCURIEs  \
# 0                                      ENVO:01001110
# 1                                      ENVO:01001110
# 2                                      ENVO:01001110
# 3                                      ENVO:01001110
# 4  CHEBI:37527,ENVO:00001996,ENVO:00000083,ENVO:0...
#
#                                                 TYPE  \
# 0                              biolink:OntologyClass
# 1                              biolink:OntologyClass
# 2                              biolink:OntologyClass
# 3                              biolink:OntologyClass
# 4  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                         MATCHED TERM  \
# 0                                          ecosystem
# 1                                          ecosystem
# 2                                          ecosystem
# 3                                          ecosystem
# 4  Acid,Mine Drainage,Mountain,Mountain,Mountain,...
#
#                                       PREFERRED FORM
# 0                                          ecosystem
# 1                                          ecosystem
# 2                                          ecosystem
# 3                                          ecosystem
# 4  acid,mine drainage,hill,mount,mountain,seamoun...

# %%
onlyFalsePosWithText = onlyFalsePosivitesDF.merge(goldInput, on='id', how='inner')
onlyFalsePosWithText = onlyFalsePosWithText.drop_duplicates()
onlyFalsePosWithText.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 1  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 2  gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 3  gold:Gb0050974   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 4  gold:Gb0050975   ENVO:00002030   ENVO:00001997  ENVO:00002034
#
#    env_broad_matched  env_local_matched  env_medium_matched  \
# 0              False              False               False
# 1              False              False               False
# 2              False              False               False
# 3              False              False               False
# 4              False              False               False
#
#   env_broad_match_type env_local_match_type env_medium_match_type  \
# 0      DescendantMatch              NoMatch               NoMatch
# 1      DescendantMatch              NoMatch               NoMatch
# 2      DescendantMatch              NoMatch               NoMatch
# 3      DescendantMatch              NoMatch               NoMatch
# 4              NoMatch              NoMatch               NoMatch
#
#                                  falsePositiveCURIEs  \
# 0                                      ENVO:01001110
# 1                                      ENVO:01001110
# 2                                      ENVO:01001110
# 3                                      ENVO:01001110
# 4  CHEBI:37527,ENVO:00001996,ENVO:00000083,ENVO:0...
#
#                                                 TYPE  \
# 0                              biolink:OntologyClass
# 1                              biolink:OntologyClass
# 2                              biolink:OntologyClass
# 3                              biolink:OntologyClass
# 4  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                         MATCHED TERM  \
# 0                                          ecosystem
# 1                                          ecosystem
# 2                                          ecosystem
# 3                                          ecosystem
# 4  Acid,Mine Drainage,Mountain,Mountain,Mountain,...
#
#                                       PREFERRED FORM  \
# 0                                          ecosystem
# 1                                          ecosystem
# 2                                          ecosystem
# 3                                          ecosystem
# 4  acid,mine drainage,hill,mount,mountain,seamoun...
#
#                                                 text
# 0  Soil ecosystem from  different sites within th...
# 1  Soil ecosystem from  different sites within th...
# 2  Soil ecosystem from  different sites within th...
# 3  Soil ecosystem from  different sites within th...
# 4  Acid Mine Drainage (ARMAN) microbial communiti...

# %%
onlyFalsePosWithText.to_csv(outputDir+'onlyFalsePosWithText.tsv', sep='\t', index=None)

# %%
allDf = pd.read_csv(outputDir+'AllGroupedById.tsv', sep='\t', low_memory=False)
allDf.head()
# Out:
#                id env_broad_scale env_local_scale     env_medium  \
# 0  gold:Gb0050971   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 1  gold:Gb0050972   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 2  gold:Gb0050973   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 3  gold:Gb0050974   ENVO:00000446   ENVO:01001785  ENVO:00001998
# 4  gold:Gb0050975   ENVO:00002030   ENVO:00001997  ENVO:00002034
#
#                                                 TYPE  \
# 0        biolink:OntologyClass,biolink:OntologyClass
# 1        biolink:OntologyClass,biolink:OntologyClass
# 2        biolink:OntologyClass,biolink:OntologyClass
# 3        biolink:OntologyClass,biolink:OntologyClass
# 4  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                         MATCHED TERM  \
# 0                                     Soil,ecosystem
# 1                                     Soil,ecosystem
# 2                                     Soil,ecosystem
# 3                                     Soil,ecosystem
# 4  Acid,Acid Mine Drainage,Biofilm,Mine Drainage,...
#
#                                       PREFERRED FORM  \
# 0                                     soil,ecosystem
# 1                                     soil,ecosystem
# 2                                     soil,ecosystem
# 3                                     soil,ecosystem
# 4  acid,acid mine drainage,biofilm,mine drainage,...
#
#                                                CURIE  \
# 0                        ENVO:00001998,ENVO:01001110
# 1                        ENVO:00001998,ENVO:01001110
# 2                        ENVO:00001998,ENVO:01001110
# 3                        ENVO:00001998,ENVO:01001110
# 4  CHEBI:37527,ENVO:00001997,ENVO:00002034,ENVO:0...
#
#                                    env_broad_matched  \
# 0                                        FALSE,FALSE
# 1                                        FALSE,FALSE
# 2                                        FALSE,FALSE
# 3                                        FALSE,FALSE
# 4  FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALS...
#
#                                    env_local_matched  \
# 0                                        FALSE,FALSE
# 1                                        FALSE,FALSE
# 2                                        FALSE,FALSE
# 3                                        FALSE,FALSE
# 4  FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                   env_medium_matched  \
# 0                                         TRUE,FALSE
# 1                                         TRUE,FALSE
# 2                                         TRUE,FALSE
# 3                                         TRUE,FALSE
# 4  FALSE,FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                 env_broad_match_type  \
# 0                            NoMatch,DescendantMatch
# 1                            NoMatch,DescendantMatch
# 2                            NoMatch,DescendantMatch
# 3                            NoMatch,DescendantMatch
# 4  NoMatch,NoMatch,NoMatch,NoMatch,NoMatch,NoMatc...
#
#                                 env_local_match_type  \
# 0                                    NoMatch,NoMatch
# 1                                    NoMatch,NoMatch
# 2                                    NoMatch,NoMatch
# 3                                    NoMatch,NoMatch
# 4  NoMatch,ExactMatch,NoMatch,DescendantMatch,NoM...
#
#                                env_medium_match_type  \
# 0                                 ExactMatch,NoMatch
# 1                                 ExactMatch,NoMatch
# 2                                 ExactMatch,NoMatch
# 3                                 ExactMatch,NoMatch
# 4  NoMatch,NoMatch,ExactMatch,NoMatch,NoMatch,NoM...
#
#                                   false_positives  \
# 0                                      FALSE,TRUE
# 1                                      FALSE,TRUE
# 2                                      FALSE,TRUE
# 3                                      FALSE,TRUE
# 4  TRUE,FALSE,FALSE,TRUE,TRUE,TRUE,TRUE,TRUE,TRUE
#
#                                            Ancestors  \
# 0  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 1  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 2  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 3  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 4  [['CHEBI:51086', 'CHEBI:50906']]|[['ENVO:00000...
#
#                                          Descendants
# 0  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 1  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 2  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 3  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 4  [['CHEBI:39143', 'CHEBI:48356', 'CHEBI:48360',...

# %%
allWithTextDF = allDf.merge(goldInput, on='id', how='inner')
allWithTextDF.insert(2,'env_broad_label',allWithTextDF['env_broad_scale'].apply(lambda x: ont.label(x)))
allWithTextDF.insert(4,'env_local_label',allWithTextDF['env_local_scale'].apply(lambda x: ont.label(x)))
allWithTextDF.insert(6,'env_medium_label',allWithTextDF['env_medium'].apply(lambda x: ont.label(x)))
allWithTextDF.head()
# Out:
#                id env_broad_scale    env_broad_label env_local_scale  \
# 0  gold:Gb0050971   ENVO:00000446  terrestrial biome   ENVO:01001785
# 1  gold:Gb0050972   ENVO:00000446  terrestrial biome   ENVO:01001785
# 2  gold:Gb0050973   ENVO:00000446  terrestrial biome   ENVO:01001785
# 3  gold:Gb0050974   ENVO:00000446  terrestrial biome   ENVO:01001785
# 4  gold:Gb0050975   ENVO:00002030      aquatic biome   ENVO:00001997
#
#       env_local_label     env_medium env_medium_label  \
# 0                land  ENVO:00001998             soil
# 1                land  ENVO:00001998             soil
# 2                land  ENVO:00001998             soil
# 3                land  ENVO:00001998             soil
# 4  acid mine drainage  ENVO:00002034          biofilm
#
#                                                 TYPE  \
# 0        biolink:OntologyClass,biolink:OntologyClass
# 1        biolink:OntologyClass,biolink:OntologyClass
# 2        biolink:OntologyClass,biolink:OntologyClass
# 3        biolink:OntologyClass,biolink:OntologyClass
# 4  biolink:ChemicalSubstance,biolink:OntologyClas...
#
#                                         MATCHED TERM  \
# 0                                     Soil,ecosystem
# 1                                     Soil,ecosystem
# 2                                     Soil,ecosystem
# 3                                     Soil,ecosystem
# 4  Acid,Acid Mine Drainage,Biofilm,Mine Drainage,...
#
#                                       PREFERRED FORM  ...  \
# 0                                     soil,ecosystem  ...
# 1                                     soil,ecosystem  ...
# 2                                     soil,ecosystem  ...
# 3                                     soil,ecosystem  ...
# 4  acid,acid mine drainage,biofilm,mine drainage,...  ...
#
#                                    env_broad_matched  \
# 0                                        FALSE,FALSE
# 1                                        FALSE,FALSE
# 2                                        FALSE,FALSE
# 3                                        FALSE,FALSE
# 4  FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE,FALS...
#
#                                    env_local_matched  \
# 0                                        FALSE,FALSE
# 1                                        FALSE,FALSE
# 2                                        FALSE,FALSE
# 3                                        FALSE,FALSE
# 4  FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                   env_medium_matched  \
# 0                                         TRUE,FALSE
# 1                                         TRUE,FALSE
# 2                                         TRUE,FALSE
# 3                                         TRUE,FALSE
# 4  FALSE,FALSE,TRUE,FALSE,FALSE,FALSE,FALSE,FALSE...
#
#                                 env_broad_match_type  \
# 0                            NoMatch,DescendantMatch
# 1                            NoMatch,DescendantMatch
# 2                            NoMatch,DescendantMatch
# 3                            NoMatch,DescendantMatch
# 4  NoMatch,NoMatch,NoMatch,NoMatch,NoMatch,NoMatc...
#
#                                 env_local_match_type  \
# 0                                    NoMatch,NoMatch
# 1                                    NoMatch,NoMatch
# 2                                    NoMatch,NoMatch
# 3                                    NoMatch,NoMatch
# 4  NoMatch,ExactMatch,NoMatch,DescendantMatch,NoM...
#
#                                env_medium_match_type  \
# 0                                 ExactMatch,NoMatch
# 1                                 ExactMatch,NoMatch
# 2                                 ExactMatch,NoMatch
# 3                                 ExactMatch,NoMatch
# 4  NoMatch,NoMatch,ExactMatch,NoMatch,NoMatch,NoM...
#
#                                   false_positives  \
# 0                                      FALSE,TRUE
# 1                                      FALSE,TRUE
# 2                                      FALSE,TRUE
# 3                                      FALSE,TRUE
# 4  TRUE,FALSE,FALSE,TRUE,TRUE,TRUE,TRUE,TRUE,TRUE
#
#                                            Ancestors  \
# 0  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 1  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 2  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 3  [['BFO:0000040', 'ENVO:00010483', 'BFO:0000001...
# 4  [['CHEBI:51086', 'CHEBI:50906']]|[['ENVO:00000...
#
#                                          Descendants  \
# 0  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 1  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 2  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 3  [['ENVO:00005752', 'ENVO:00003082', 'ENVO:0000...
# 4  [['CHEBI:39143', 'CHEBI:48356', 'CHEBI:48360',...
#
#                                                 text
# 0  Soil ecosystem from  different sites within th...
# 1  Soil ecosystem from  different sites within th...
# 2  Soil ecosystem from  different sites within th...
# 3  Soil ecosystem from  different sites within th...
# 4  Acid Mine Drainage (ARMAN) microbial communiti...
#
# [5 rows x 21 columns]

# %%
allWithTextDF.to_csv(outputDir+'AllWithText.tsv', sep='\t', index=None)
