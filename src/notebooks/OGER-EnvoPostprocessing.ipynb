# %% [markdown]
# ## Import OGER output

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %%time

import pandas as pd
import seaborn as sns
from datetime import datetime
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# CPU times: user 1.47 s, sys: 868 ms, total: 2.34 s
# Wall time: 57.7 s

# %%
cols = ['BiosampleId', 'Biolink', 'BeginTerm', 'EndTerm', 'TokenizedTerm', 'PreferredTerm', 'CURIE', 'NaN1', 'S-Type', 'NaN2', 'UMLS_CUI']
ogerOutput = pd.read_csv('../nlpOutput/FullNLPOutput-Envo.tsv', sep='\t', names=cols )
ogerOutput = ogerOutput.drop(['NaN1', 'NaN2', 'UMLS_CUI'], axis = 1)
print('Total number of rows: ', str(len(ogerOutput)))
ogerOutput.head()
#pd.set_option("display.max_rows", None)
#print(ogerOutput.CURIE.value_counts())
# Out:
# Total number of rows:  2386121
#     BiosampleId                   Biolink  BeginTerm  EndTerm TokenizedTerm  \
# 0  SAMN10586215     biolink:OntologyClass         16       24      contains
# 1  SAMN10586215  biolink:OrganismalEntity        119      127      Bacteria
# 2  SAMN05720810     biolink:OntologyClass         50       57       part of
# 3  SAMN05720810     biolink:OntologyClass         79       90   Agriculture
# 4  SAMN05720810     biolink:OntologyClass         79       90   Agriculture
#
#           PreferredTerm          CURIE S-Type
# 0              contains     RO:0001019     S1
# 1              Bacteria    NCBITaxon:2     S1
# 2               part of    BFO:0000050     S1
# 3  agricultural process  ENVO:01001246     S1
# 4      animal husbandry  ENVO:01001248     S1

# %% [markdown]
# ### Functions

# %%
def annotatePlot(axs, yLim, valueAngle=0, xyDist=20):
    for p in axs.patches:
             axs.annotate("%.d" % p.get_height(), (p.get_x() + p.get_width() / 2, p.get_height()),
                 ha='center', va='center', fontsize=20, color='black', xytext=(0, xyDist),
                 textcoords='offset points', rotation = valueAngle)
    _ = axs.set_ylim(0,yLim) #To make space for the annotations

def drawPlot(ontology, topTermCount=50):
    termOntoEnvo = termOnto[termOnto.CURIE == ontology]
    sns.set(rc={'figure.figsize':(20,8)})
    axs = sns.countplot(x = termOntoEnvo.TokenizedTerm, data = termOntoEnvo, order=termOntoEnvo.TokenizedTerm.value_counts().iloc[:topTermCount].index)
    axs.set_title('Top '+str(topTermCount)+' terms from ' + ontology, fontsize=30)
    axs.set_xlabel("Terms",fontsize=20)
    axs.set_ylabel("Counts",fontsize=20)
    axs.tick_params(labelsize=20)
    axs.set_xticklabels(axs.get_xticklabels(), rotation=90)
    
    return axs
    
# Function to phrase-ify: Form Phrases for each biosample
                        # Phrase = list of all terms recognized by OGER

def phrasify(dataFrame, columnNames):
    count = 0
    returnDF = pd.DataFrame(columns=columnNames)
    
    bsIdList = dataFrame.BiosampleId.unique()
    
    for i in bsIdList:
        count += 1
        tmpDF = pd.DataFrame()
        bpList = []
        phrase1 = []
        phrase2 = []
        curie = []

        tmpDF = dataFrame.loc[(dataFrame.BiosampleId == i)]
        
        # Filter: Consider ONLY 3 or more DISTINCT terms AND if an RO CURIE is present
        
        #if len(tmpDF) > 2 \
        #and len(tmpDF.TokenizedTerm.unique()) > 2 \
        #and tmpDF.CURIE.str.contains('RO').any():
            
        tmpDF.sort_values(by=['BeginTerm'], inplace=True)

        for row in tmpDF.iterrows():
            bpList.append(row[1].BeginTerm)
            phrase1.append(row[1].TokenizedTerm)
            phrase2.append(row[1].PreferredTerm)
            curie.append(row[1].CURIE)

        returnDF = returnDF.append(pd.DataFrame([[i, bpList, phrase1, phrase2, curie]], columns=columnNames))
            
        if count % 1000 == 0:
            print('Number of relevant rows: '+ str(len(returnDF))+ ' - '+ datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
        
        # *********** FOR DEBUG PURPOSES ONLY ****************
        #if count == 5000:
        #    break;
        
    return returnDF

# %% [markdown]
# ## NLP output breakdown

# %%
# %%time
termOnto = ogerOutput[['TokenizedTerm', 'PreferredTerm', 'CURIE']]
termOnto.CURIE = termOnto['CURIE'].str.split(':').map(lambda x: x[0])
termOnto.TokenizedTerm = termOnto.TokenizedTerm.str.lower()
termOnto.head()
# Out:
# CPU times: user 5.94 s, sys: 392 ms, total: 6.34 s
# Wall time: 7.08 s
#   TokenizedTerm         PreferredTerm      CURIE
# 0      contains              contains         RO
# 1      bacteria              Bacteria  NCBITaxon
# 2       part of               part of        BFO
# 3   agriculture  agricultural process       ENVO
# 4   agriculture      animal husbandry       ENVO

# %%
# %%time
sns.set(rc={'figure.figsize':(14,8)})
nlpAx = sns.countplot(x = termOnto.CURIE, data = termOnto)
nlpAx.set_title('Ontology breakdown', fontsize=20)
nlpAx.set_xlabel("Ontologies",fontsize=20)
nlpAx.set_ylabel("Counts",fontsize=20)
nlpAx.tick_params(labelsize=20)
nlpAx.set_xticklabels(nlpAx.get_xticklabels(), rotation=90)

annotatePlot(nlpAx, 1000000)
# Out:
# CPU times: user 2.93 s, sys: 107 ms, total: 3.04 s
# Wall time: 3.9 s

# %% [markdown]
# ## ENVO

# %%
nlpEnvoAx = drawPlot('ENVO')
annotatePlot(nlpEnvoAx, 90000, 90, 30)

# %% [markdown]
# ## OBO

# %%
nlpOboAx = drawPlot('OBO')
annotatePlot(nlpOboAx, 35000, 90, 30)

# %% [markdown]
# ## RO

# %%
nlpRoAx = drawPlot('RO', 25)
annotatePlot(nlpRoAx, 90000, 90, 30)

# %% [markdown]
# ## NCBITaxon

# %%
nlpNcbiAx = drawPlot('NCBITaxon')
annotatePlot(nlpNcbiAx, 180000, 90, 35)

# %% [markdown]
# ## BFO

# %%
nlpBfoAx = drawPlot('BFO', 15)
annotatePlot(nlpBfoAx, 400000, 90, 40)

# %% [markdown]
# ## CHEBI

# %%
nlpCheAx = drawPlot('CHEBI')
annotatePlot(nlpCheAx, 90000, 90, 40)

# %% [markdown]
# ## UBERON

# %%
nlpUbeAx = drawPlot('UBERON')
annotatePlot(nlpUbeAx, 85000, 90, 40)

# %% [markdown]
# ## PO

# %%
nlpUbeAx = drawPlot('PO', 10)
annotatePlot(nlpUbeAx, 7500, 0, 20)

# %% [markdown]
# ## IAO

# %%
nlpIaoAx = drawPlot('IAO', 8)
annotatePlot(nlpIaoAx, 4500, 0, 20)

# %% [markdown]
# ## WD_Entity

# %%
nlpWdeAx = drawPlot('WD_Entity', 3)
annotatePlot(nlpWdeAx, 2500, 0, 20)

# %% [markdown]
# ## OBI

# %%
nlpObiAx = drawPlot('OBI', 2)
annotatePlot(nlpObiAx, 5000, 0, 20)

# %% [markdown]
# ## GO

# %%
nlpGoAx = drawPlot('GO', 5)
annotatePlot(nlpGoAx, 1000, 0, 20)

# %% [markdown]
# ## OIO

# %%
nlpOioAx = drawPlot('OIO', 5)
annotatePlot(nlpOioAx, 120, 0, 20)

# %% [markdown]
# ## Import OGER Input

# %%
ogerInput = pd.read_csv('../output/biosampleDescriptionDF.tsv', sep='\t')
ogerInput.BiosampleId = ogerInput.BiosampleId.map(lambda x: x.replace('BIOSAMPLE:',''))
ogerInput = ogerInput.drop(['StudyId', 'Name', 'Title'], axis = 1)
print('Number of rows: '+ str(len(ogerInput)))
print('Number of unique Ids: '+ str(len(ogerInput.BiosampleId.unique())))
print('Number of unique Desc: '+ str(len(ogerInput.Description.unique())))
ogerInput = ogerInput.drop_duplicates()
print('******After duplicate row removal*****')
print('Number of rows: '+ str(len(ogerInput)))
print('Number of unique Ids: '+ str(len(ogerInput.BiosampleId.unique())))
print('Number of unique Description: '+ str(len(ogerInput.Description.unique())))
ogerInput.head()
# Out:
# Number of rows: 948401
# Number of unique Ids: 938333
# Number of unique Desc: 59789
# ******After duplicate row removal*****
# Number of rows: 947374
# Number of unique Ids: 938333
# Number of unique Description: 59789
#                                          Description   BiosampleId
# 0  Treponema denticola ATCC 35405. Treponema dent...  SAMN02603967
# 1  Treponema pallidum subsp. pallidum. This organ...  SAMN02604348
# 2  Campylobacter fetus subsp. venerealis str. Azu...  SAMN02471365
# 3  Campylobacter jejuni strain NCTC11168. This st...  SAMEA1705929
# 4  Francisella tularensis subsp. tularensis strai...  SAMEA3138185

# %%
# Serching for negation in a very naive fashion

searchfor = [' not ', 'fail', 'absent', 'negative']
test = ogerInput.where(lambda x: x.Description.str.contains('|'.join(searchfor))).dropna()

test.drop_duplicates().head()
# Out:
#                                           Description   BiosampleId
# 1   Treponema pallidum subsp. pallidum. This organ...  SAMN02604348
# 12  Sinorhizobium meliloti strain 1021. Streptomyc...  SAMEA3283068
# 13  Methylobacterium extorquens strain AM1. This s...  SAMN02604258
# 17  Bordetella bronchiseptica strain RB50. This st...  SAMEA1705943
# 18  Bordetella parapertussis strain 12822 . This s...  SAMEA1705915

# %%
print('Unique BiosampleIds: '+ str(len(ogerOutput.BiosampleId.unique())))
print('Unique CURIEs: '+ str(len(ogerOutput.CURIE.unique())))
print('Unique Biolinks: '+ str(len(ogerOutput.Biolink.unique())))
print('Unique Standard Terms: '+ str(len(ogerOutput.PreferredTerm.unique())))
# Out:
# Unique BiosampleIds: 649677
# Unique CURIEs: 1686
# Unique Biolinks: 4
# Unique Standard Terms: 1677

# %%
'''curieOfInterest = ['ENVO', 'PATO', 'RO']
envoPato = ogerOutput[ogerOutput.CURIE.str.contains('|'.join(curieOfInterest))]
print('Number of rows: '+ str(len(envoPato)))
envoPato.head()'''

# %%
'''salineTerms = ['sali', 'salt']
envPatSal = envoPato[envoPato.TokenizedTerm	.str.contains('|'.join(salineTerms))]
print('Number of rows: '+ str(len(envPatSal)))
envPatSal.head()'''

# %%
# Get list of IDs from structured data file

fp = '../input/water-related-samples.tsv.gz'
#fp = '../input/non-human-samples.tsv.gz'

structuredDataDF = pd.read_csv(fp, sep='\t', low_memory=False)
print('Number of rows: ', str(len(structuredDataDF)))
structuredDataDF.head()
# Out:
# Number of rows:  18615
#   tot_diss_nitro salinity_meth tidal_stage num_replicons nitrate  \
# 0            NaN           NaN         NaN           NaN     NaN
# 1            NaN           NaN         NaN           NaN     NaN
# 2            NaN           NaN         NaN           NaN     NaN
# 3            NaN           NaN         NaN           NaN     NaN
# 4            NaN           NaN         NaN           NaN     NaN
#
#   rel_to_oxygen potassium sodium env_package biomass samp_store_dur conduc  \
# 0           NaN      2.33    NaN       water     NaN            NaN    4.7
# 1           NaN      1.33    NaN       water     NaN            NaN    4.7
# 2           NaN      2.77    NaN       water     NaN            NaN    4.6
# 3           NaN      2.52    NaN       water     NaN            NaN   11.6
# 4           NaN       3.4    NaN       water     NaN            NaN   11.6
#
#   propagation     samp_mat_process host_taxid phosphate light_intensity  \
# 0         NaN  Sterivex filtration        NaN       NaN             NaN
# 1         NaN  Sterivex filtration        NaN       NaN             NaN
# 2         NaN  Sterivex filtration        NaN       NaN             NaN
# 3         NaN  Sterivex filtration        NaN       NaN             NaN
# 4         NaN  Sterivex filtration        NaN       NaN             NaN
#
#   geo_loc_name tot_depth_water_col  tot_carb estimated_size samp_salinity  \
# 0        Spain                 NaN       NaN            NaN           NaN
# 1        Spain                 NaN       NaN            NaN           NaN
# 2        Spain                 NaN       NaN            NaN           NaN
# 3        Spain                 NaN       NaN            NaN           NaN
# 4        Spain                 NaN       NaN            NaN           NaN
#
#   diss_org_carb phaeopigments host_life_stage biotic_relationship host_age  \
# 0           NaN           NaN             NaN                 NaN      NaN
# 1           NaN           NaN             NaN                 NaN      NaN
# 2           NaN           NaN             NaN                 NaN      NaN
# 3           NaN           NaN             NaN                 NaN      NaN
# 4           NaN           NaN             NaN                 NaN      NaN
#
#   nitrite ref_biomaterial isol_growth_condt atmospheric_data density  \
# 0     NaN             NaN               NaN              NaN     NaN
# 1     NaN             NaN               NaN              NaN     NaN
# 2     NaN             NaN               NaN              NaN     NaN
# 3     NaN             NaN               NaN              NaN     NaN
# 4     NaN             NaN               NaN              NaN     NaN
#
#          project_name salinity elev misc_param sulfate slope_aspect  \
# 0  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 1  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 2  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 3  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 4  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
#
#   investigation_type collection_date  extreme_salinity temp turbidity  \
# 0       miens-survey      2002-11-02               NaN  NaN       NaN
# 1       miens-survey      2002-11-02               NaN  NaN       NaN
# 2       miens-survey      2002-11-02               NaN  NaN       NaN
# 3       miens-survey      2002-11-02               NaN  NaN       NaN
# 4       miens-survey      2002-11-02               NaN  NaN       NaN
#
#   suspend_part_matter pressure samp_store_loc env_broad_scale samp_size  \
# 0                 NaN      NaN            NaN             NaN       NaN
# 1                 NaN      NaN            NaN             NaN       NaN
# 2                 NaN      NaN            NaN             NaN       NaN
# 3                 NaN      NaN            NaN             NaN       NaN
# 4                 NaN      NaN            NaN             NaN       NaN
#
#   diss_carb_dioxide org_nitro tot_nitro samp_vol_we_dna_ext  \
# 0               NaN       NaN       NaN                 NaN
# 1               NaN       NaN       NaN                 NaN
# 2               NaN       NaN       NaN                 NaN
# 3               NaN       NaN       NaN                 NaN
# 4               NaN       NaN       NaN                 NaN
#
#                                    heavy_metals_meth oxy_stat_samp  \
# 0  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 1  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 2  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 3  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 4  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
#
#   env_local_scale redox_potential bacteria_carb_prod diss_org_nitro  \
# 0             NaN             463                NaN            NaN
# 1             NaN             461                NaN            NaN
# 2             NaN             460                NaN            NaN
# 3             NaN             393                NaN            NaN
# 4             NaN             397                NaN            NaN
#
#   organism_count perturbation n_alkanes chloride tot_phosp org_carb  \
# 0            NaN          NaN       NaN      NaN       NaN      NaN
# 1            NaN          NaN       NaN      NaN       NaN      NaN
# 2            NaN          NaN       NaN      NaN       NaN      NaN
# 3            NaN          NaN       NaN      NaN       NaN      NaN
# 4            NaN          NaN       NaN      NaN       NaN      NaN
#
#    carb_nitro_ratio diss_oxygen part_org_carb alkalinity env_medium  \
# 0               NaN         NaN           NaN        NaN        NaN
# 1               NaN         NaN           NaN        NaN        NaN
# 2               NaN         NaN           NaN        NaN        NaN
# 3               NaN         NaN           NaN        NaN        NaN
# 4               NaN         NaN           NaN        NaN        NaN
#
#   primary_prod fluor diss_inorg_carb part_org_nitro chlorophyll oxygen  \
# 0          NaN   NaN             NaN            NaN         NaN    NaN
# 1          NaN   NaN             NaN            NaN         NaN    NaN
# 2          NaN   NaN             NaN            NaN         NaN    NaN
# 3          NaN   NaN             NaN            NaN         NaN    NaN
# 4          NaN   NaN             NaN            NaN         NaN    NaN
#
#   host_height samp_collect_device ammonium nitro wind_speed  \
# 0         NaN              Bottle      NaN   NaN        NaN
# 1         NaN              Bottle      NaN   NaN        NaN
# 2         NaN              Bottle      NaN   NaN        NaN
# 3         NaN              Bottle      NaN   NaN        NaN
# 4         NaN              Bottle      NaN   NaN        NaN
#
#                    lat_lon    ph ph_meth magnesium ploidy samp_store_temp  \
# 0  37.72498333 N 6.56025 W  2.28     NaN       NaN    NaN             NaN
# 1  37.72498333 N 6.56025 W  2.28     NaN       NaN    NaN             NaN
# 2  37.72498333 N 6.56025 W  2.28     NaN       NaN    NaN             NaN
# 3       37.7249 N 6.5625 W  1.95     NaN       NaN    NaN             NaN
# 4       37.7249 N 6.5625 W  1.97     NaN       NaN    NaN             NaN
#
#   experimental_factor depth silicate  tot_part_carb trophic_level calcium  \
# 0                 NaN   NaN      NaN            NaN           NaN   87.66
# 1                 NaN   NaN      NaN            NaN           NaN   62.28
# 2                 NaN   NaN      NaN            NaN           NaN   87.05
# 3                 NaN   NaN      NaN            NaN           NaN  126.11
# 4                 NaN   NaN      NaN            NaN           NaN  332.17
#
#                        id  taxonomy_id          taxonomy_name      package  \
# 0  BIOSAMPLE:SAMEA1706329       449393  freshwater metagenome  Generic.1.0
# 1  BIOSAMPLE:SAMEA1706311       449393  freshwater metagenome  Generic.1.0
# 2  BIOSAMPLE:SAMEA1706320       449393  freshwater metagenome  Generic.1.0
# 3  BIOSAMPLE:SAMEA1706300       449393  freshwater metagenome  Generic.1.0
# 4  BIOSAMPLE:SAMEA1706316       449393  freshwater metagenome  Generic.1.0
#
#   norm_env_package
# 0            water
# 1            water
# 2            water
# 3            water
# 4            water

# %% [markdown]
# ### Get OGER data corresponding to the ones present in structured data

# %% [markdown]
# #### From OGER Input

# %%
structDataID = structuredDataDF.id.str.replace('BIOSAMPLE:','')
structDataIdDF = pd.DataFrame(structDataID)
structDataOgerInput = ogerInput.merge(structDataIdDF, how='inner', left_on='BiosampleId', right_on='id')
structDataOgerInput = structDataOgerInput.drop(['id'], axis = 1)
print('Number of rows: '+ str(len(structDataOgerInput)))
structDataOgerInput.head()
# Out:
# Number of rows: 243
#                                          Description   BiosampleId
# 0  Purple microbial (Photo- and chemosynthetic) m...  SAMN02228699
# 1  Purple microbial (Photo- and chemosynthetic) m...  SAMN02228700
# 2  Purple microbial (Photo- and chemosynthetic) m...  SAMN02228701
# 3  Purple microbial (Photo- and chemosynthetic) m...  SAMN02228702
# 4  Purple microbial (Photo- and chemosynthetic) m...  SAMN02228703

# %% [markdown]
# #### From OGER output

# %%
structDataOgerOutput = ogerOutput.merge(structDataIdDF, how='inner', left_on='BiosampleId', right_on='id')
structDataOgerOutput = structDataOgerOutput.drop(['id'], axis = 1)
print('Number of row: '+ str(len(structDataOgerOutput)))
structDataOgerOutput.head()
# Out:
# Number of row: 2429
#     BiosampleId                    Biolink  BeginTerm  EndTerm TokenizedTerm  \
# 0  SAMN02393652  biolink:ChemicalSubstance         19       24         probe
# 1  SAMN02393652      biolink:OntologyClass         61       65          soil
# 2  SAMN02393652   biolink:AnatomicalEntity         70       73           gut
# 3  SAMN02393652      biolink:OntologyClass         70       73           gut
# 4  SAMN02393652   biolink:AnatomicalEntity         70       73           gut
#
#       PreferredTerm           CURIE S-Type
# 0             probe     CHEBI:50406     S1
# 1              soil   ENVO:00001998     S1
# 2   digestive tract  UBERON:0001555     S1
# 3       watercourse   ENVO:00000029     S1
# 4  digestive system  UBERON:0001007     S1

# %%
# %%time

pCols = ['BiosampleId', 'BeginPosList', 'Phrase', 'StdPhrase', 'CURIE']
phraseDF = phrasify(structDataOgerOutput,pCols)
print('*****Number of rows: '+ str(len(phraseDF)) + ' ********')
phraseDF.head()
# Out:
# *****Number of rows: 238 ********
# CPU times: user 1.11 s, sys: 17.5 ms, total: 1.13 s
# Wall time: 1.16 s
#     BiosampleId                                       BeginPosList  \
# 0  SAMN02393652                          [19, 61, 70, 70, 70, 208]
# 0  SAMN02389811  [20, 48, 179, 189, 202, 202, 221, 221, 241, 25...
# 0  SAMN02251077   [65, 98, 188, 198, 216, 231, 259, 259, 273, 273]
# 0  SAMEA2620360                           [42, 160, 200, 231, 231]
# 0  SAMN02009298  [63, 63, 63, 68, 89, 93, 138, 143, 201, 236, 4...
#
#                                               Phrase  \
# 0             [probe, soil, gut, gut, gut, function]
# 0  [aquarium, mesocosm, part of, flow, system, sy...
# 0  [bacteria, lagoon, site, temperate, lagoon, fr...
# 0           [seawater, Ocean, all, quality, quality]
# 0  [deep, deep, deep, sea, Sea, rift, halo, strat...
#
#                                            StdPhrase  \
# 0  [probe, soil, digestive tract, watercourse, di...
# 0  [aquarium, mesocosm, part of, mass wasting flo...
# 0  [Bacteria, lagoon, site, temperate, lagoon, fr...
# 0         [sea water, ocean, root, quality, quality]
# 0  [undersea trough, ocean trench, increased dept...
#
#                                                CURIE
# 0  [CHEBI:50406, ENVO:00001998, UBERON:0001555, E...
# 0  [ENVO:00002196, ENVO:01000620, BFO:0000050, EN...
# 0  [NCBITaxon:2, ENVO:00000038, BFO:0000029, ENVO...
# 0  [ENVO:00002149, ENVO:00000015, NCBITaxon:1, OB...
# 0  [ENVO:01000654, ENVO:00000275, OBO:PATO_000159...

# %%
# Join with ogerInput to get the description

phraseWithDescDF = phraseDF.merge(structDataOgerInput, how='right', on='BiosampleId').dropna()
print('*****Number of rows: '+ str(len(phraseWithDescDF)) + ' ********')
phraseWithDescDF.head()
# Out:
# *****Number of rows: 237 ********
#     BiosampleId                                       BeginPosList  \
# 0  SAMN02228699  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 1  SAMN02228700  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 2  SAMN02228701  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 3  SAMN02228702  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 4  SAMN02228703  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
#
#                                               Phrase  \
# 0  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 1  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 2  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 3  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 4  [sink, sink, located in, Lake, Lake, Lake, Lak...
#
#                                            StdPhrase  \
# 0  [sink fixture, sinkhole, located in, pond, int...
# 1  [sink fixture, sinkhole, located in, pond, int...
# 2  [sink fixture, sinkhole, located in, pond, int...
# 3  [sink fixture, sinkhole, located in, pond, int...
# 4  [sink fixture, sinkhole, located in, pond, int...
#
#                                                CURIE  \
# 0  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 1  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 2  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 3  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 4  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
#
#                                          Description
# 0  Purple microbial (Photo- and chemosynthetic) m...
# 1  Purple microbial (Photo- and chemosynthetic) m...
# 2  Purple microbial (Photo- and chemosynthetic) m...
# 3  Purple microbial (Photo- and chemosynthetic) m...
# 4  Purple microbial (Photo- and chemosynthetic) m...

# %%
# Add prefix 'BIOSAMPLE:' to the id 
phraseWithDescDF.BiosampleId = 'BIOSAMPLE:' + phraseWithDescDF.BiosampleId
phraseWithDescDF.head()
# Out:
#               BiosampleId                                       BeginPosList  \
# 0  BIOSAMPLE:SAMN02228699  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 1  BIOSAMPLE:SAMN02228700  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 2  BIOSAMPLE:SAMN02228701  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 3  BIOSAMPLE:SAMN02228702  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
# 4  BIOSAMPLE:SAMN02228703  [82, 82, 93, 104, 104, 104, 104, 104, 104, 104...
#
#                                               Phrase  \
# 0  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 1  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 2  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 3  [sink, sink, located in, Lake, Lake, Lake, Lak...
# 4  [sink, sink, located in, Lake, Lake, Lake, Lak...
#
#                                            StdPhrase  \
# 0  [sink fixture, sinkhole, located in, pond, int...
# 1  [sink fixture, sinkhole, located in, pond, int...
# 2  [sink fixture, sinkhole, located in, pond, int...
# 3  [sink fixture, sinkhole, located in, pond, int...
# 4  [sink fixture, sinkhole, located in, pond, int...
#
#                                                CURIE  \
# 0  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 1  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 2  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 3  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
# 4  [ENVO:01000990, ENVO:00000195, RO:0001025, ENV...
#
#                                          Description
# 0  Purple microbial (Photo- and chemosynthetic) m...
# 1  Purple microbial (Photo- and chemosynthetic) m...
# 2  Purple microbial (Photo- and chemosynthetic) m...
# 3  Purple microbial (Photo- and chemosynthetic) m...
# 4  Purple microbial (Photo- and chemosynthetic) m...

# %%
result = structuredDataDF.merge(phraseWithDescDF, how='left', left_on='id', right_on='BiosampleId')
print('Number of rows: '+ str(len(result)))
result.head()
# Out:
# Number of rows: 18617
#   tot_diss_nitro salinity_meth tidal_stage num_replicons nitrate  \
# 0            NaN           NaN         NaN           NaN     NaN
# 1            NaN           NaN         NaN           NaN     NaN
# 2            NaN           NaN         NaN           NaN     NaN
# 3            NaN           NaN         NaN           NaN     NaN
# 4            NaN           NaN         NaN           NaN     NaN
#
#   rel_to_oxygen potassium sodium env_package biomass samp_store_dur conduc  \
# 0           NaN      2.33    NaN       water     NaN            NaN    4.7
# 1           NaN      1.33    NaN       water     NaN            NaN    4.7
# 2           NaN      2.77    NaN       water     NaN            NaN    4.6
# 3           NaN      2.52    NaN       water     NaN            NaN   11.6
# 4           NaN       3.4    NaN       water     NaN            NaN   11.6
#
#   propagation     samp_mat_process host_taxid phosphate light_intensity  \
# 0         NaN  Sterivex filtration        NaN       NaN             NaN
# 1         NaN  Sterivex filtration        NaN       NaN             NaN
# 2         NaN  Sterivex filtration        NaN       NaN             NaN
# 3         NaN  Sterivex filtration        NaN       NaN             NaN
# 4         NaN  Sterivex filtration        NaN       NaN             NaN
#
#   geo_loc_name tot_depth_water_col  tot_carb estimated_size samp_salinity  \
# 0        Spain                 NaN       NaN            NaN           NaN
# 1        Spain                 NaN       NaN            NaN           NaN
# 2        Spain                 NaN       NaN            NaN           NaN
# 3        Spain                 NaN       NaN            NaN           NaN
# 4        Spain                 NaN       NaN            NaN           NaN
#
#   diss_org_carb phaeopigments host_life_stage biotic_relationship host_age  \
# 0           NaN           NaN             NaN                 NaN      NaN
# 1           NaN           NaN             NaN                 NaN      NaN
# 2           NaN           NaN             NaN                 NaN      NaN
# 3           NaN           NaN             NaN                 NaN      NaN
# 4           NaN           NaN             NaN                 NaN      NaN
#
#   nitrite ref_biomaterial isol_growth_condt atmospheric_data density  \
# 0     NaN             NaN               NaN              NaN     NaN
# 1     NaN             NaN               NaN              NaN     NaN
# 2     NaN             NaN               NaN              NaN     NaN
# 3     NaN             NaN               NaN              NaN     NaN
# 4     NaN             NaN               NaN              NaN     NaN
#
#          project_name salinity elev misc_param sulfate slope_aspect  \
# 0  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 1  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 2  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 3  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
# 4  Rio Tinto 3 Domain      NaN  NaN        NaN     NaN          NaN
#
#   investigation_type collection_date  extreme_salinity temp turbidity  \
# 0       miens-survey      2002-11-02               NaN  NaN       NaN
# 1       miens-survey      2002-11-02               NaN  NaN       NaN
# 2       miens-survey      2002-11-02               NaN  NaN       NaN
# 3       miens-survey      2002-11-02               NaN  NaN       NaN
# 4       miens-survey      2002-11-02               NaN  NaN       NaN
#
#   suspend_part_matter pressure samp_store_loc env_broad_scale samp_size  \
# 0                 NaN      NaN            NaN             NaN       NaN
# 1                 NaN      NaN            NaN             NaN       NaN
# 2                 NaN      NaN            NaN             NaN       NaN
# 3                 NaN      NaN            NaN             NaN       NaN
# 4                 NaN      NaN            NaN             NaN       NaN
#
#   diss_carb_dioxide org_nitro tot_nitro samp_vol_we_dna_ext  \
# 0               NaN       NaN       NaN                 NaN
# 1               NaN       NaN       NaN                 NaN
# 2               NaN       NaN       NaN                 NaN
# 3               NaN       NaN       NaN                 NaN
# 4               NaN       NaN       NaN                 NaN
#
#                                    heavy_metals_meth oxy_stat_samp  \
# 0  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 1  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 2  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 3  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
# 4  Palacios C, Zettler E, Amils R, Amaral-Zettler...           NaN
#
#   env_local_scale redox_potential bacteria_carb_prod diss_org_nitro  \
# 0             NaN             463                NaN            NaN
# 1             NaN             461                NaN            NaN
# 2             NaN             460                NaN            NaN
# 3             NaN             393                NaN            NaN
# 4             NaN             397                NaN            NaN
#
#   organism_count perturbation n_alkanes chloride tot_phosp org_carb  \
# 0            NaN          NaN       NaN      NaN       NaN      NaN
# 1            NaN          NaN       NaN      NaN       NaN      NaN
# 2            NaN          NaN       NaN      NaN       NaN      NaN
# 3            NaN          NaN       NaN      NaN       NaN      NaN
# 4            NaN          NaN       NaN      NaN       NaN      NaN
#
#    carb_nitro_ratio diss_oxygen part_org_carb alkalinity env_medium  \
# 0               NaN         NaN           NaN        NaN        NaN
# 1               NaN         NaN           NaN        NaN        NaN
# 2               NaN         NaN           NaN        NaN        NaN
# 3               NaN         NaN           NaN        NaN        NaN
# 4               NaN         NaN           NaN        NaN        NaN
#
#   primary_prod fluor diss_inorg_carb part_org_nitro chlorophyll oxygen  \
# 0          NaN   NaN             NaN            NaN         NaN    NaN
# 1          NaN   NaN             NaN            NaN         NaN    NaN
# 2          NaN   NaN             NaN            NaN         NaN    NaN
# 3          NaN   NaN             NaN            NaN         NaN    NaN
# 4          NaN   NaN             NaN            NaN         NaN    NaN
#
#   host_height samp_collect_device ammonium nitro wind_speed  \
# 0         NaN              Bottle      NaN   NaN        NaN
# 1         NaN              Bottle      NaN   NaN        NaN
# 2         NaN              Bottle      NaN   NaN        NaN
# 3         NaN              Bottle      NaN   NaN        NaN
# 4         NaN              Bottle      NaN   NaN        NaN
#
#                    lat_lon    ph ph_meth magnesium ploidy samp_store_temp  \
# 0  37.72498333 N 6.56025 W  2.28     NaN       NaN    NaN             NaN
# 1  37.72498333 N 6.56025 W  2.28     NaN       NaN    NaN             NaN
# 2  37.72498333 N 6.56025 W  2.28     NaN       NaN    NaN             NaN
# 3       37.7249 N 6.5625 W  1.95     NaN       NaN    NaN             NaN
# 4       37.7249 N 6.5625 W  1.97     NaN       NaN    NaN             NaN
#
#   experimental_factor depth silicate  tot_part_carb trophic_level calcium  \
# 0                 NaN   NaN      NaN            NaN           NaN   87.66
# 1                 NaN   NaN      NaN            NaN           NaN   62.28
# 2                 NaN   NaN      NaN            NaN           NaN   87.05
# 3                 NaN   NaN      NaN            NaN           NaN  126.11
# 4                 NaN   NaN      NaN            NaN           NaN  332.17
#
#                        id  taxonomy_id          taxonomy_name      package  \
# 0  BIOSAMPLE:SAMEA1706329       449393  freshwater metagenome  Generic.1.0
# 1  BIOSAMPLE:SAMEA1706311       449393  freshwater metagenome  Generic.1.0
# 2  BIOSAMPLE:SAMEA1706320       449393  freshwater metagenome  Generic.1.0
# 3  BIOSAMPLE:SAMEA1706300       449393  freshwater metagenome  Generic.1.0
# 4  BIOSAMPLE:SAMEA1706316       449393  freshwater metagenome  Generic.1.0
#
#   norm_env_package BiosampleId BeginPosList Phrase StdPhrase CURIE Description
# 0            water         NaN          NaN    NaN       NaN   NaN         NaN
# 1            water         NaN          NaN    NaN       NaN   NaN         NaN
# 2            water         NaN          NaN    NaN       NaN   NaN         NaN
# 3            water         NaN          NaN    NaN       NaN   NaN         NaN
# 4            water         NaN          NaN    NaN       NaN   NaN         NaN

# %%
result.to_csv('../output/waterSampleWithEnitityPhrases-Envo.tsv', sep='\t', index=False)

# %%
packageVsBiosample = pd.DataFrame(result.BiosampleId).set_index(result.env_package)
counts = packageVsBiosample.groupby(['env_package']).agg(len)
print("Counts regardless of NLP data")
print(counts)
# Out:
# Counts regardless of NLP data
#                                     BiosampleId
# env_package
# Coastal water body (ENVO:02000049)            1
# Deep-sea water                                1
# MIGS/MIMS/MIMARKS.wastewater                385
# MIGS/MIMS/MIMARKS.water                    1765
# MIMARKS_water                                 6
# Sea water                                     1
# Water                                         3
# fresh water                                  27
# sea water                                     2
# sea water, [ENVO:00002149]                    1
# seawater                                      9
# sterile water                                35
# wastewater                                   14
# water                                     16367

# %%
biosamplePackage = result[['BiosampleId', 'env_package']]
biosamplePackage = biosamplePackage.dropna()
sns.set(rc={'figure.figsize':(12,8)})
ax = sns.countplot(x = biosamplePackage.env_package, data = biosamplePackage)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title('Env-Packages by NLP result counts', fontsize=30)
ax.set_xlabel("Env Package",fontsize=20)
ax.set_ylabel("Counts",fontsize=20)
ax.tick_params(labelsize=20)

annotatePlot(ax, 120)
