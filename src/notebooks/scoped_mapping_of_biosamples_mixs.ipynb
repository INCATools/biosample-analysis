# %%
import pandas as pd
import re
import requests as requests
import sqlite3
import string
import urllib
import yaml

import scoped_mapping

from datetime import datetime
from pkg_resources import get_distribution, DistributionNotFound
from strsimpy.cosine import Cosine
from xml.etree import ElementTree
from tdda import rexpy

import math

# from copy import deepcopy

# %% [markdown]
# # Settings required from user:
#
# See repo README for notes on setting up SQLite databases of OBO ontologies with semantic-sql, relation-graph and rdftab

# %% [markdown]
# ### How should the mapping effort be scoped?
# Additional taxonomic filters may be applied below
# - soil
# - sediment
# - plant-associated
# - ( water )

# %%
scoping_col = "env_package_normalization.EnvPackage"
scoping_value = "water"

# %% [markdown]
# ### What Biosample field should be mapped to ontology classes?
# - env_broad_scale
# - env_local_scale
# - env_medium

# %%
biosample_col_to_map = "env_medium"

# %%
# USE CONSISTENT CAPITALIZASTION FOR ONTOLOGY NAMES
# where do we require a single ontology and where can we use multiple?
primary_onto_prefix = "ENVO"
# AVOID ncit, gaz
# additional_preferred_ontologies = ["obi", "pato", "efo"]
additional_preferred_ontologies = ["po", "ncbitaxon"]
# additional_preferred_ontologies = ["ncbitaxon", "po"]

# ontology choce and ranking: root should probably be interpreted as a part plant, 
#   not as the common ancestory of all life forms

# %%
# from https://www.ncbi.nlm.nih.gov/biosample/docs/packages/?format=xml
# see also https://www.ncbi.nlm.nih.gov/biosample/docs/packages/
biosample_packages_file = "../../target/biosample_packages.xml"

# from ftp://ftp.ncbi.nlm.nih.gov//biosample/biosample_set.xml.gz
# via harmonized_table.db.gz
# in https://drive.google.com/drive/u/0/folders/1eL0v0stoduahjDpoDJIk3z2pJBAU4b2Y
biosample_sqlite_file = "../../target/harmonized-table.db"
ncbitaxon_sqlite_file = "../../../scoped-mapping/semantic-sql/db/ncbitaxon.db"

primary_ontology_sqlite_prefix = "../../../scoped-mapping/semantic-sql/db/"

chars_to_whiteout = "._-"
my_query_fields = ""  # OLS weighted default
my_row_req = 3

# what is this relative to the max distance?
my_string_dist_arg = 2

my_max_string_dist = 0.1
salvage_max_dist = 0.2

xquery_pivot_in_cell_delim = "|||"
rejoin_delim = "|"

# %% [markdown]
# ### Settings for manual review of OLS search-based results
# Results based on merging Biosample annotations to ontology classes by label or embedded ID are not exported for review at this time

# %%
# ols_review_file = "../local/ols_review.tsv"
ols_review_seperator = "\t"

strategy_col = "strategy"
include_col = "include"

first_pass_include_val = True

salvage_include_val = False

# %% [markdown]
# ### Settings for SSSOM output

# %%
sssom_subject_prefix = biosample_col_to_map + "_" + scoping_col + "_" + scoping_value
sssom_file = "../../target/" + sssom_subject_prefix + "_SSSOM.tsv"

# %%
# per_biosample_mapping_results_file = "per_biosample_scoped_mapping_results.tsv"

# %% [markdown]
# ----

# %%
biosample_cnx = sqlite3.connect(biosample_sqlite_file)
ncbitaxon_cnx = sqlite3.connect(ncbitaxon_sqlite_file)
primary_ontology_sqlite_file = (
    primary_ontology_sqlite_prefix + primary_onto_prefix.lower() + ".db"
)
primary_ontology_cnx = sqlite3.connect(primary_ontology_sqlite_file)
additional_preferred_ontologies.insert(0, primary_onto_prefix.lower())
additional_preferred_ontologies_str = ",".join(additional_preferred_ontologies)

# %%
q = "select * from id_patterns"
[id_patterns_frame, query_duration] = scoped_mapping.timed_query(q, biosample_cnx)
id_patterns_frame
# Out:
#      ontology     id_pattern
# 0         BFO      BFO:\d{7}
# 1        CARO     CARO:\d{7}
# 2       CHEBI  CHEBI:\d{4,6}
# 3        ENVO   ENVO:\d{7,8}
# 4         FAO    FAO:0000001
# 5      FOODON   FOODON:\d{8}
# 6          GO       GO:\d{7}
# 7         IAO      IAO:\d{7}
# 8   NCBITaxon  NCBITaxon:\d+
# 9         OBI      OBI:\d{7}
# 10       PATO     PATO:\d{7}
# 11        PCO      PCO:\d{7}
# 12         PO       PO:\d{7}
# 13         RO     RO:0002577
# 14     UBERON   UBERON:\d{7}

# %%
id_patterns = dict(zip(id_patterns_frame.ontology, id_patterns_frame.id_pattern))

# %% [markdown]
# - env_package = env_package annotation from NCBI Biosample file XXX
# - count = number of biosamples using that env_package annotation
# - lhs = checklist info
# - rhs = potential package info
# - extract = potential OBO ID from rhs column (currently harcoded and only looking for ENVO IDs)
# - remaining_string = rhs/string, with potential OBO IDs removed
# - remaining_tidied = remaining_string with case, whitespace and punctuation normailzastion
# - rt_override = some remaining_tidied values can be replaced according to env_package_overrides
# - EnvPackage = corresponding de-normalized value from package_dictionary
# - is_canonical = false when EnvPackage is NaN

# %%
# cursor = biosample_cnx.cursor()
# cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
# print(cursor.fetchall())

# %%
q = "select * from env_package_normalization"
[env_package_normalization, query_duration] = scoped_mapping.timed_query(
    q, biosample_cnx
)

# %% [markdown]
# ## Get a table of MIxS annotations to be mapped to ontology classes.
#
# Explicitly scope based on normalized package data. These values were set at the top of this notebook.

# %%
print(biosample_col_to_map)
print(scoping_col)
print(scoping_value)
# Out:
# env_medium
# env_package_normalization.EnvPackage
# water

# %% [markdown]
# **In this case, the scoping includes an inner join requirement for 'unclassified entities'**

# %%
q = (
    "select "
    + biosample_col_to_map
    + """, count(*) as count
from
    biosample b
join env_package_normalization on
    b.env_package = env_package_normalization.env_package
inner join biosample_sample_taxon_summary stic on
    b.taxonomy_id = stic.biosample_taxid
where """
    + scoping_col
    + " = '"
    + scoping_value
    + "' group by "
    + biosample_col_to_map
    + """
order by
    count(*) desc"""
)

[mapping_candidates, query_duration] = scoped_mapping.timed_query(q, biosample_cnx)

mapping_candidates.to_csv("mapping_candidates.csv")

# %% [markdown]
# ----
#
# ## The Biosample format allows for pipe-delimited environmental package lists.
#
# They haven't been tidied yet.
#
# Singletons haven't been filtered out.
# - keep them because some may be easy to map anyway?
#
# Separate those out into their components.
#
# ----

# %%
multi_frames = []
for row in mapping_candidates.itertuples(index=True, name="PandaZ"):
    split_check = row[1]
    if split_check is None:
        split_check = ""
    splitted = pd.Series(split_check.split(xquery_pivot_in_cell_delim))
    splitted_count = len(splitted)
    repeated = [split_check] * splitted_count
    repeated = pd.Series(repeated)
    as_frame = pd.DataFrame(dict(repeated=repeated, splitted=splitted)).reset_index()
    seq_list = list(range(1, splitted_count + 1))
    as_frame["part_count"] = splitted_count
    as_frame["seq"] = seq_list
    multi_frames.append(as_frame)
concat_frame = pd.concat(multi_frames)
concat_frame = concat_frame[["repeated", "splitted", "part_count", "seq"]]

# %%
mapping_candidates = mapping_candidates.merge(
    concat_frame, left_on=biosample_col_to_map, right_on="repeated", how="left"
)

mapping_candidates
# Out:
#                                             env_medium  count  \
# 0                                          fresh water   5847
# 1                                                water   1913
# 2                            sea water [ENVO:00002149]   1100
# 3    particulate matter, including plankton (ENVO:x...    941
# 4                                                 2225    879
# ..                                                 ...    ...
# 208  seawater/brine transition zone lower halocline...      1
# 209  seawater/brine transition zone lower halocline...      1
# 210  seawater/brine transition zone upper halocline...      1
# 211  seawater/brine transition zone upper halocline...      1
# 212                      water from hydrothermal plume      1
#
#                                               repeated  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                               splitted  part_count  seq
# 0                                          fresh water           1    1
# 1                                                water           1    1
# 2                            sea water [ENVO:00002149]           1    1
# 3    particulate matter, including plankton (ENVO:x...           1    1
# 4                                                 2225           1    1
# ..                                                 ...         ...  ...
# 208  seawater/brine transition zone lower halocline...           1    1
# 209  seawater/brine transition zone lower halocline...           1    1
# 210  seawater/brine transition zone upper halocline...           1    1
# 211  seawater/brine transition zone upper halocline...           1    1
# 212                      water from hydrothermal plume           1    1
#
# [213 rows x 6 columns]

# %% [markdown]
# ## Normalize a few different ways `OBO` IDs have been entered
# In the Biosample metadata

# %%
# this helps by standardizing what could be an ID
#   but if the RHS is text, then "envo" should just be removed
mapping_candidates["term_tidy"] = mapping_candidates.splitted.str.replace(
    primary_onto_prefix.lower() + "[:_ ]",
    primary_onto_prefix + ":",
    regex=True,
    case=False,
)

# %% [markdown]
# # Now try to extract ontology terms that are already present

# %%
# should try joining agsinst additional SQLite ontology databases
candidate_series_decomposition = scoped_mapping.decompose_series(
    mapping_candidates["term_tidy"], id_patterns[primary_onto_prefix]
)

mapping_candidates = pd.concat(
    [mapping_candidates, candidate_series_decomposition], axis=1
)

mapping_candidates[
    "remaining_tidied"
] = mapping_candidates.remaining_tidied.str.replace(
    primary_onto_prefix.lower() + "[:_ ]", "", regex=True, case=False
)

# %% [markdown]
# ## Join the extracted IDs with their labels
#
# _Start by connecting to the rdftab database from which the terms and label-like annotations will be obtained?_

# %% [markdown]
# ## extracting the labels

# %%
q = "select stanza as subject, value from ids_labs_selected_ontolgies"

[onto_labels, query_duration] = scoped_mapping.timed_query(q, biosample_cnx)

onto_labels
# Out:
#               subject                                  value
# 0         BFO:0000001                                 entity
# 1         BFO:0000002                             continuant
# 2         BFO:0000003                              occurrent
# 3         BFO:0000004                 independent continuant
# 4         BFO:0000006                         spatial region
# ...               ...                                    ...
# 13129  UBERON:3000972     head external integument structure
# 13130  UBERON:3000977     body external integument structure
# 13131  UBERON:3010200  vasculature of respiratory integument
# 13132  UBERON:4100000            skeletal element projection
# 13133  UBERON:8410024                    intestinal junction
#
# [13134 rows x 2 columns]

# %% [markdown]
# ## and merging

# %%
mapping_candidates = mapping_candidates.merge(
    onto_labels, left_on="extract", right_on="subject", how="left"
)

# %%
mapping_candidates.to_csv("mapping_candidates.csv")

# %% [markdown]
# ## Use cosine string distance to see if the labels match closely enough
#
# I.e. the labels claimed by the Biosample data set and the labels asserted in the ontology. if they're close enough, consider the assigned ID legit
#
# _How close is close enough?_

# %%
my_cosine_obj = Cosine(my_string_dist_arg)
mapping_candidates["value"] = mapping_candidates["value"].fillna("")
mapping_candidates["remaining_tidied"] = mapping_candidates["remaining_tidied"].fillna(
    ""
)
mapping_candidates["cosine"] = mapping_candidates.apply(
    lambda my_row: my_cosine_obj.distance(
        my_row["remaining_tidied"].lower(), my_row["value"].lower()
    ),
    axis=1,
)

# %% [markdown]
# **Previously, we did a reality check on the claimed IDs and labels. If a label is claimed without any ID, that could still be a path to an ontology term.**
#
# We'll be doing some merging, so make sure column names are meaningful and unique

# %%
# what's a better pattern for subsetting and renaming columns?

mapping_candidates.columns = [
    biosample_col_to_map,
    "count",
    "repeated",
    "splitted",
    "part_count",
    "seq",
    "term_tidy",
    "string",
    "extract",
    "remaining_string",
    "remaining_tidied",
    "term_id",
    "lab_from_id",
    "lfi_cosine",
]
mapping_candidates = mapping_candidates.merge(
    onto_labels, left_on="remaining_tidied", right_on="value", how="left"
)

mapping_candidates.columns = [
    biosample_col_to_map,
    "count",
    "repeated",
    "splitted",
    "part_count",
    "seq",
    "term_tidy",
    "string",
    "extract",
    "remaining_string",
    "remaining_tidied",
    "term_id",
    "lab_from_id",
    "lfi_cosine",
    "term_id_from_lab",
    "value",
]

mapping_candidates = mapping_candidates.drop_duplicates()

# mapping_candidates

# %%
mc_tifl_split = mapping_candidates["term_id_from_lab"].str.split(":")

prefix_when_possible = []
for one_split in mc_tifl_split:
    if type(one_split) == list:
        os_first = one_split[0]
        prefix_when_possible.append(os_first)
    else:
        prefix_when_possible.append("")

prefix_when_possible = [each_string.lower() for each_string in prefix_when_possible]

# prefix_when_possible

# %%
# WHY DID I MAKE THIS SO COMPLICATED?

# if "onto_prefix" in mapping_candidates.columns:
#     mapping_candidates = mapping_candidates.drop("onto_prefix", 1)

# mapping_candidates = mapping_candidates.assign(onto_prefix='')

mapping_candidates['onto_prefix'] = prefix_when_possible

# mapping_candidates

# %%
ranks = list(range(len(additional_preferred_ontologies)))

d = {"onto_prefix": additional_preferred_ontologies, "rank": ranks}
onto_rank_frame = pd.DataFrame(d)

onto_rank_frame
# Out:
#   onto_prefix  rank
# 0        envo     0
# 1          po     1
# 2   ncbitaxon     2

# %%
mapping_candidates = mapping_candidates.merge(
    onto_rank_frame, on="onto_prefix", how="left"
)

# mapping_candidates

# %%
best_maps = mapping_candidates.groupby(biosample_col_to_map)["rank"].min().reset_index()

# best_maps

# %%
mapping_candidates = mapping_candidates.merge(
    best_maps, on=[biosample_col_to_map, "rank"]
)

mapping_candidates
# Out:
#                                             env_medium  count  \
# 0                                          fresh water   5847
# 1                                                water   1913
# 2                            sea water [ENVO:00002149]   1100
# 3    particulate matter, including plankton (ENVO:x...    941
# 4                                                 2225    879
# ..                                                 ...    ...
# 208  seawater/brine transition zone lower halocline...      1
# 209  seawater/brine transition zone lower halocline...      1
# 210  seawater/brine transition zone upper halocline...      1
# 211  seawater/brine transition zone upper halocline...      1
# 212                      water from hydrothermal plume      1
#
#                                               repeated  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                               splitted  part_count  seq  \
# 0                                          fresh water           1    1
# 1                                                water           1    1
# 2                            sea water [ENVO:00002149]           1    1
# 3    particulate matter, including plankton (ENVO:x...           1    1
# 4                                                 2225           1    1
# ..                                                 ...         ...  ...
# 208  seawater/brine transition zone lower halocline...           1    1
# 209  seawater/brine transition zone lower halocline...           1    1
# 210  seawater/brine transition zone upper halocline...           1    1
# 211  seawater/brine transition zone upper halocline...           1    1
# 212                      water from hydrothermal plume           1    1
#
#                                              term_tidy  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                                 string        extract  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]  ENVO:00002149
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...            ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                       remaining_string  \
# 0                                          fresh water
# 1                                                water
# 2                                           sea water
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                       remaining_tidied        term_id  \
# 0                                          fresh water            NaN
# 1                                                water            NaN
# 2                                            sea water  ENVO:00002149
# 3       particulate matter including plankton xxxxxxxx            NaN
# 4                                                 2225            NaN
# ..                                                 ...            ...
# 208  seawater brine transition zone lower halocline...            NaN
# 209  seawater brine transition zone lower halocline...            NaN
# 210  seawater brine transition zone upper halocline...            NaN
# 211  seawater brine transition zone upper halocline...            NaN
# 212                      water from hydrothermal plume            NaN
#
#     lab_from_id  lfi_cosine term_id_from_lab        value onto_prefix  rank
# 0                       1.0    ENVO:00002011  fresh water        envo   0.0
# 1                       1.0      CHEBI:15377        water       chebi   NaN
# 2     sea water         0.0    ENVO:00002149    sea water        envo   0.0
# 3                       1.0              NaN          NaN               NaN
# 4                       1.0              NaN          NaN               NaN
# ..          ...         ...              ...          ...         ...   ...
# 208                     1.0              NaN          NaN               NaN
# 209                     1.0              NaN          NaN               NaN
# 210                     1.0              NaN          NaN               NaN
# 211                     1.0              NaN          NaN               NaN
# 212                     1.0              NaN          NaN               NaN
#
# [213 rows x 18 columns]

# %% [markdown]
# ## Find consensus term IDs and labels

# %%
mapping_candidates["consensus_id"] = mapping_candidates["term_id_from_lab"]
mapping_candidates["consensus_lab"] = mapping_candidates["value"]

flag = mapping_candidates["consensus_id"].isnull() & (
    (
        ~mapping_candidates["term_id"].isnull()
        & mapping_candidates.lfi_cosine.le(my_max_string_dist)
    )
    | (
        ~mapping_candidates["term_id"].isnull()
        & mapping_candidates["remaining_tidied"].eq("")
    )
)

replacements = mapping_candidates.loc[flag, "term_id"]
mapping_candidates.loc[flag, "consensus_id"] = replacements

replacements = mapping_candidates.loc[flag, "lab_from_id"]
mapping_candidates.loc[flag, "consensus_lab"] = replacements

flag = mapping_candidates.consensus_id.isna()
antiflag = ~flag
mapping_candidates["id_or_lab_ok"] = antiflag

mapping_candidates["assembled_consensus"] = (
    mapping_candidates["consensus_lab"]
    + " ["
    + mapping_candidates["consensus_id"]
    + "]"
)

# %%
mapping_candidates
# Out:
#                                             env_medium  count  \
# 0                                          fresh water   5847
# 1                                                water   1913
# 2                            sea water [ENVO:00002149]   1100
# 3    particulate matter, including plankton (ENVO:x...    941
# 4                                                 2225    879
# ..                                                 ...    ...
# 208  seawater/brine transition zone lower halocline...      1
# 209  seawater/brine transition zone lower halocline...      1
# 210  seawater/brine transition zone upper halocline...      1
# 211  seawater/brine transition zone upper halocline...      1
# 212                      water from hydrothermal plume      1
#
#                                               repeated  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                               splitted  part_count  seq  \
# 0                                          fresh water           1    1
# 1                                                water           1    1
# 2                            sea water [ENVO:00002149]           1    1
# 3    particulate matter, including plankton (ENVO:x...           1    1
# 4                                                 2225           1    1
# ..                                                 ...         ...  ...
# 208  seawater/brine transition zone lower halocline...           1    1
# 209  seawater/brine transition zone lower halocline...           1    1
# 210  seawater/brine transition zone upper halocline...           1    1
# 211  seawater/brine transition zone upper halocline...           1    1
# 212                      water from hydrothermal plume           1    1
#
#                                              term_tidy  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                                 string        extract  \
# 0                                          fresh water
# 1                                                water
# 2                            sea water [ENVO:00002149]  ENVO:00002149
# 3    particulate matter, including plankton (ENVO:x...
# 4                                                 2225
# ..                                                 ...            ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                       remaining_string  ... lab_from_id  \
# 0                                          fresh water  ...
# 1                                                water  ...
# 2                                           sea water   ...   sea water
# 3    particulate matter, including plankton (ENVO:x...  ...
# 4                                                 2225  ...
# ..                                                 ...  ...         ...
# 208  seawater/brine transition zone lower halocline...  ...
# 209  seawater/brine transition zone lower halocline...  ...
# 210  seawater/brine transition zone upper halocline...  ...
# 211  seawater/brine transition zone upper halocline...  ...
# 212                      water from hydrothermal plume  ...
#
#     lfi_cosine term_id_from_lab        value onto_prefix rank   consensus_id  \
# 0          1.0    ENVO:00002011  fresh water        envo  0.0  ENVO:00002011
# 1          1.0      CHEBI:15377        water       chebi  NaN    CHEBI:15377
# 2          0.0    ENVO:00002149    sea water        envo  0.0  ENVO:00002149
# 3          1.0              NaN          NaN              NaN            NaN
# 4          1.0              NaN          NaN              NaN            NaN
# ..         ...              ...          ...         ...  ...            ...
# 208        1.0              NaN          NaN              NaN            NaN
# 209        1.0              NaN          NaN              NaN            NaN
# 210        1.0              NaN          NaN              NaN            NaN
# 211        1.0              NaN          NaN              NaN            NaN
# 212        1.0              NaN          NaN              NaN            NaN
#
#      consensus_lab id_or_lab_ok          assembled_consensus
# 0      fresh water         True  fresh water [ENVO:00002011]
# 1            water         True          water [CHEBI:15377]
# 2        sea water         True    sea water [ENVO:00002149]
# 3              NaN        False                          NaN
# 4              NaN        False                          NaN
# ..             ...          ...                          ...
# 208            NaN        False                          NaN
# 209            NaN        False                          NaN
# 210            NaN        False                          NaN
# 211            NaN        False                          NaN
# 212            NaN        False                          NaN
#
# [213 rows x 22 columns]

# %% [markdown]
# ## For which Biosample annotations were no easy mappings found?
# How many Biosamples uses those annotations?

# %%
flag = ~mapping_candidates.id_or_lab_ok
needs_search = mapping_candidates.loc[flag]

needs_search = needs_search[["remaining_tidied", "count"]]

sum_by_needed = needs_search.groupby("remaining_tidied")["count"].sum()

sum_by_needed = sum_by_needed.to_frame()
sum_by_needed["remaining_tidied"] = sum_by_needed.index

sum_by_needed = sum_by_needed.sort_values("count", ascending=False)
sum_by_needed = sum_by_needed.reset_index(drop=True)

sum_by_needed

# sum_by_needed.to_sql("sum_by_needed", biosample_cnx, if_exists="replace", index=False)
# Out:
#      count                                remaining_tidied
# 0      941  particulate matter including plankton xxxxxxxx
# 1      879                                            2225
# 2      850                                         1000060
# 3      844
# 4      517                                        seawater
# ..     ...                                             ...
# 105      1                                   rhizosphere 6
# 106      1                                   rhizosphere 7
# 107      1                                   rhizosphere 8
# 108      1                                   rhizosphere 9
# 109      1                                   niskin bottle
#
# [110 rows x 2 columns]

# %%
# remove singletons
sum_by_needed['keep_flag'] = sum_by_needed['count'].gt(1)

sum_by_needed = sum_by_needed.loc[sum_by_needed['keep_flag']]
sum_by_needed
# Out:
#     count                                remaining_tidied  keep_flag
# 0     941  particulate matter including plankton xxxxxxxx       True
# 1     879                                            2225       True
# 2     850                                         1000060       True
# 3     844                                                       True
# 4     517                                        seawater       True
# ..    ...                                             ...        ...
# 65      2                        deep chlorophyll maximum       True
# 66      2                        brownish colored sea ice       True
# 67      2                         supraglacial lake water       True
# 68      2                             sterivex cartridges       True
# 69      2                                              vv       True
#
# [70 rows x 3 columns]

# %% [markdown]
# ## Extract the tidied strings

# %%
generic_raw_list = list(sum_by_needed["remaining_tidied"])
generic_raw_list.sort()

# %% [markdown]
# ## Submit those tidied strings to a search engine
#
# Specifically OLS search. This takes roughly one second per unique post-tidied submission
#
# _Turn logging back on to show status?_
# _Print the count and pre- and post- datestamps_
# `datetime.now().replace(microsecond=0).isoformat()` ?

# %%
print(datetime.now().replace(microsecond=0).isoformat())
print(len(sum_by_needed.index))
# Out:
# 2021-07-07T08:08:17
# 70

# %%
generic_search_res = scoped_mapping.search_get_annotations_wrapper(
    generic_raw_list,
    bad_chars=chars_to_whiteout,
    cat_name=biosample_col_to_map,
    ontoprefix=additional_preferred_ontologies_str,
    query_fields="",
    rr=my_row_req,
    string_dist_arg=my_string_dist_arg,
)
# generic_search_res.to_sql(
#     "ols_search_results", biosample_cnx, if_exists="replace", index=False
# )

# %% [markdown]
# ## Filter out the best of the acceptable mappings
# From a string distance perspective

# %% [markdown]
# save generic_search_res to db?

# %%
my_best_acceptable = scoped_mapping.get_best_acceptable(
    generic_search_res, max_string_dist=my_max_string_dist
)

# %%
if my_best_acceptable is None:
    pass
else:
    my_best_acceptable = my_best_acceptable.assign(category='preferred ontologies')

# %%
my_best_acceptable
# Out:
#                  category                       raw                     query  \
# 26   preferred ontologies  brownish colored sea ice  brownish colored sea ice
# 43   preferred ontologies             coastal water             coastal water
# 105  preferred ontologies                freshwater                freshwater
# 238  preferred ontologies               ocean water               ocean water
# 305  preferred ontologies                  seawater                  seawater
#
#                          name  string_dist_rank  string_dist         obo_id  \
# 26   brownish colored sea ice                 1          0.0  ENVO:01001190
# 43              coastal water                 1          0.0  ENVO:00002150
# 105                freshwater                 1          0.0  ENVO:00002011
# 238               ocean water                 1          0.0  ENVO:00002149
# 305                  seawater                 1          0.0  ENVO:00002149
#
#                  label  search_rank ontology_prefix              scope  \
# 26       brown sea ice            1            ENVO            synonym
# 43   coastal sea water            1            ENVO  has_broad_synonym
# 105        fresh water            1            ENVO            synonym
# 238          sea water            1            ENVO            synonym
# 305          sea water            1            ENVO            synonym
#
#            type                                           iri ontology_name
# 26      synonym  http://purl.obolibrary.org/obo/ENVO_01001190          envo
# 43   annotation  http://purl.obolibrary.org/obo/ENVO_00002150          envo
# 105     synonym  http://purl.obolibrary.org/obo/ENVO_00002011          envo
# 238     synonym  http://purl.obolibrary.org/obo/ENVO_00002149          envo
# 305     synonym  http://purl.obolibrary.org/obo/ENVO_00002149          envo

# %% [markdown]
# ----
#
# ## Filter out the submissions with no acceptable matches

# %%
no_acceptable_mappings = scoped_mapping.get_no_acceptable_mappings(
    generic_search_res, my_best_acceptable
)

# %% [markdown]
# ## Try searching the failures against all ontologies in OLS
# what would it be like to use a local OLS instance? (latency-wise)

# %%
still_unmapped = list(set(list(no_acceptable_mappings["raw"])))
still_unmapped.sort()

print(len(still_unmapped))

still_unmapped
# Out:
# 65
# ['',
#  '00002110',
#  '00002150',
#  '1000060',
#  '2225',
#  'aluminum',
#  'aquifer water',
#  'borehole water',
#  'brass plastic',
#  'cardboard',
#  'cast iron',
#  'cdna libraries generated from cells filtered from seawater',
#  'ci',
#  'deep chlorophyll maximum',
#  'diffuse fluid',
#  'dna',
#  'dna isolated from cells filtered from seawater',
#  'encrusting benthic community',
#  'env 00002010',
#  'environmental dna extracted from a hot spring',
#  'filtered seawater xxxxxxxxx',
#  'filtered water',
#  'for seawater',
#  'free living fraction',
#  'genomic dna',
#  'genomic dna isolated from cells filtered from seawater',
#  'hdpe',
#  'liquid culture',
#  'liquid culture fraction 8µm',
#  'lysis buffer',
#  'marine',
#  'marine habitat',
#  'marine water',
#  'mat',
#  'mat sediment water slurry',
#  'missing',
#  'na',
#  'near bottom water',
#  'not applicable',
#  'oil water mixture',
#  'particle associated fraction',
#  'particulate matter including plankton xxxxxxxx',
#  'particulate matter including planktonic material',
#  'particulate matter xxxxxxxx including plankton xxxxxxxx',
#  'plankton',
#  'plume water',
#  'polyethylene',
#  'polypropylene',
#  'saline water including plankton xxxxxxxx',
#  'sea water oligotrophic water',
#  'sea water under sea ice',
#  'sediment water slurry',
#  'snow transect pooled',
#  'sterile flask',
#  'sterivex cartridges',
#  'supraglacial lake water',
#  'surface sea water',
#  'travertine fluid',
#  'vv',
#  'water above plume',
#  'water below plume',
#  'water chebi 15377',
#  'water column microbes',
#  'water including particulate matter such as planktonic material',
#  'water surrounding cultivated oysters vinaroz']

# %%
print(datetime.now().replace(microsecond=0).isoformat())
print(len(still_unmapped))
# Out:
# 2021-07-07T08:08:49
# 65

# %%
salvage_search_res = scoped_mapping.search_get_annotations_wrapper(
    still_unmapped,
    bad_chars="._-",
    cat_name="salvage",
    ontoprefix="",
    query_fields="",
    rr=my_row_req,
    string_dist_arg=my_string_dist_arg,
)

# salvage_search_res.to_sql(
#     "salvage_search_res", biosample_cnx, if_exists="replace", index=False
# )

# %% [markdown]
# ## We appear to be at a point of diminishing returns
# At the very least, will require some review

# %%
# remove ncit and gaz hits? 
salvage_best_acceptable = scoped_mapping.get_best_acceptable(
    salvage_search_res, max_string_dist=salvage_max_dist
)
salvage_best_acceptable
# Out:
#     category                           raw                         query  \
# 17   salvage                      aluminum                      aluminum
# 58   salvage                            ci                            ci
# 63   salvage      deep chlorophyll maximum      deep chlorophyll maximum
# 83   salvage                           dna                           dna
# 168  salvage                filtered water                filtered water
# 177  salvage                   genomic dna                   genomic dna
# 192  salvage                          hdpe                          hdpe
# 226  salvage                  lysis buffer                  lysis buffer
# 271  salvage                  marine water                  marine water
# 272  salvage                           mat                           mat
# 285  salvage                       missing                       missing
# 292  salvage                            na                            na
# 309  salvage                not applicable                not applicable
# 369  salvage                      plankton                      plankton
# 378  salvage                  polyethylene                  polyethylene
# 388  salvage                 polypropylene                 polypropylene
# 408  salvage  sea water oligotrophic water  sea water oligotrophic water
# 464  salvage       supraglacial lake water       supraglacial lake water
# 483  salvage                            vv                            vv
#
#                                name  string_dist_rank  string_dist  \
# 17                         Aluminum                 1        0.000
# 58                               ci                 1        0.000
# 63   deep chlorophyll maximum layer                 1        0.109
# 83                              DNA                 1        0.000
# 168               filtered seawater                 1        0.132
# 177                     Genomic DNA                 1        0.000
# 192                            hdpe                 1        0.000
# 226                tcl lysis buffer                 1        0.144
# 271                marine waterbody                 1        0.144
# 272                             MAT                 1        0.000
# 285                         Missing                 1        0.000
# 292                              NA                 1        0.000
# 309                  Not Applicable                 1        0.000
# 369                        Plankton                 1        0.000
# 378                    Polyethylene                 1        0.000
# 388                   polypropylene                 1        0.000
# 408              oligotrophic water                 1        0.123
# 464               supraglacial lake                 1        0.134
# 483                              VV                 1        0.000
#
#               obo_id                           label  search_rank  \
# 17       NCIT:C93162                        Aluminum            1
# 58               NaN                              ci            1
# 63     ENVO:01000326  deep chlorophyll maximum layer            1
# 83         NCIT:C449                             DNA            1
# 168    MICRO:0001773               filtered seawater            1
# 177      NCIT:C95940                     Genomic DNA            1
# 192      NCIT:C83759       High Density Polyethylene            1
# 226     NCIT:C178572                      Buffer TCL            2
# 271    ENVO:00001999               marine water body            3
# 272      format:3626                             MAT            1
# 285      NCIT:C54031                         Missing            1
# 292   CO_357:2100001                              NA            1
# 309      NCIT:C48660                  Not Applicable            1
# 369     OMIT:0011906                        Plankton            1
# 378     OMIT:0020780                    Polyethylene            1
# 388  FOODON:03500021                   polypropylene            1
# 408    ENVO:00002223              oligotrophic water            1
# 464    ENVO:03000035               supraglacial lake            1
# 483     OMIT:0056524                              VV            1
#
#     ontology_prefix    scope     type  \
# 17             NCIT    label    label
# 58              CCO    label    label
# 63             ENVO    label    label
# 83             NCIT    label    label
# 168           MICRO    label    label
# 177            NCIT    label    label
# 192            NCIT  synonym  synonym
# 226            NCIT  synonym  synonym
# 271           MICRO  synonym  synonym
# 272            EDAM    label    label
# 285            NCIT    label    label
# 292          CO_357    label    label
# 309            NCIT    label    label
# 369            OMIT    label    label
# 378            OMIT    label    label
# 388         GENEPIO    label    label
# 408            ENVO    label    label
# 464            ENVO    label    label
# 483            OMIT    label    label
#
#                                                 iri ontology_name
# 17       http://purl.obolibrary.org/obo/NCIT_C93162          ncit
# 58            http://identifiers.org/ncbigene/43767           cco
# 63     http://purl.obolibrary.org/obo/ENVO_01000326          envo
# 83         http://purl.obolibrary.org/obo/NCIT_C449          ncit
# 168    http://purl.obolibrary.org/obo/MICRO_0001773         micro
# 177      http://purl.obolibrary.org/obo/NCIT_C95940          ncit
# 192      http://purl.obolibrary.org/obo/NCIT_C83759          ncit
# 226     http://purl.obolibrary.org/obo/NCIT_C178572          ncit
# 271    http://purl.obolibrary.org/obo/ENVO_00001999         micro
# 272             http://edamontology.org/format_3626          edam
# 285      http://purl.obolibrary.org/obo/NCIT_C54031          ncit
# 292  http://www.cropontology.org/rdf/CO_357:2100001        co_357
# 309      http://purl.obolibrary.org/obo/NCIT_C48660          ncit
# 369     http://purl.obolibrary.org/obo/OMIT_0011906          omit
# 378     http://purl.obolibrary.org/obo/OMIT_0020780          omit
# 388  http://purl.obolibrary.org/obo/FOODON_03500021       genepio
# 408    http://purl.obolibrary.org/obo/ENVO_00002223          envo
# 464    http://purl.obolibrary.org/obo/ENVO_03000035          envo
# 483     http://purl.obolibrary.org/obo/OMIT_0056524          omit

# %% [markdown]
# ## Save the mappings for review!
#
# _Note that the merge on ID or label mappings are not included here_

# %%
salvage_best_acceptable[include_col] = salvage_include_val

# had been implicitly assuming that my_best_acceptable and salvage_best_acceptable
#   were both data frames, even if they had 0 rows
# this super hacky and should be temporary only
# looks like its a lott better when a function can't returna. data frame or None
# what if they are both None objects?!
if my_best_acceptable is None:
    if salvage_best_acceptable is None:
        pass
    else:
        best_and_salvage = salvage_best_acceptable
else:
    my_best_acceptable[include_col] = first_pass_include_val
    if salvage_best_acceptable is None:
        best_and_salvage = my_best_acceptable
    else:
        best_and_salvage = pd.concat([my_best_acceptable, salvage_best_acceptable])

# %%
best_and_salvage["ols_curation_notes"] = ""

# best_and_salvage.to_csv(ols_review_file, sep=ols_review_seperator, index=False)

best_and_salvage = best_and_salvage[
    [
        "category",
        "raw",
        "query",
        "name",
        "obo_id",
        "label",
        "ontology_prefix",
        "include",
        "ols_curation_notes",
        "scope",
        "type",
        "iri",
        "ontology_name",
        "string_dist_rank",
        "string_dist",
        "search_rank",
    ]
]

# %%
best_and_salvage = best_and_salvage.merge(
    onto_labels, how="left", left_on="obo_id", right_on="subject"
)

# for esoteric ontologies, may need to look up with OLS API?
#  if we want to differentialte imported and owner labels that is

# %%
best_and_salvage = best_and_salvage[
    [
        "category",
        "raw",
        "query",
        "name",
        "obo_id",
        "value",
        "label",
        "ontology_prefix",
        "include",
        "ols_curation_notes",
        "scope",
        "type",
        "iri",
        "ontology_name",
        "string_dist_rank",
        "string_dist",
        "search_rank",
    ]
]

best_and_salvage = best_and_salvage.sort_values(
    ["include", "ontology_prefix"], ascending=(True, True)
)

best_and_salvage = best_and_salvage.drop_duplicates()

best_and_salvage = best_and_salvage.reset_index(drop = True)

best_and_salvage
# Out:
#                 category                           raw  \
# 0                salvage                            ci
# 1                salvage                            na
# 2                salvage                           mat
# 3                salvage      deep chlorophyll maximum
# 4                salvage  sea water oligotrophic water
# 5                salvage       supraglacial lake water
# 6                salvage                 polypropylene
# 7                salvage                filtered water
# 8                salvage                  marine water
# 9                salvage                      aluminum
# 10               salvage                           dna
# 11               salvage                   genomic dna
# 12               salvage                          hdpe
# 13               salvage                  lysis buffer
# 14               salvage                       missing
# 15               salvage                not applicable
# 16               salvage                      plankton
# 17               salvage                  polyethylene
# 18               salvage                            vv
# 19  preferred ontologies      brownish colored sea ice
# 20  preferred ontologies                 coastal water
# 21  preferred ontologies                    freshwater
# 22  preferred ontologies                   ocean water
# 23  preferred ontologies                      seawater
#
#                            query                            name  \
# 0                             ci                              ci
# 1                             na                              NA
# 2                            mat                             MAT
# 3       deep chlorophyll maximum  deep chlorophyll maximum layer
# 4   sea water oligotrophic water              oligotrophic water
# 5        supraglacial lake water               supraglacial lake
# 6                  polypropylene                   polypropylene
# 7                 filtered water               filtered seawater
# 8                   marine water                marine waterbody
# 9                       aluminum                        Aluminum
# 10                           dna                             DNA
# 11                   genomic dna                     Genomic DNA
# 12                          hdpe                            hdpe
# 13                  lysis buffer                tcl lysis buffer
# 14                       missing                         Missing
# 15                not applicable                  Not Applicable
# 16                      plankton                        Plankton
# 17                  polyethylene                    Polyethylene
# 18                            vv                              VV
# 19      brownish colored sea ice        brownish colored sea ice
# 20                 coastal water                   coastal water
# 21                    freshwater                      freshwater
# 22                   ocean water                     ocean water
# 23                      seawater                        seawater
#
#              obo_id                           value  \
# 0               NaN                             NaN
# 1    CO_357:2100001                             NaN
# 2       format:3626                             NaN
# 3     ENVO:01000326  deep chlorophyll maximum layer
# 4     ENVO:00002223              oligotrophic water
# 5     ENVO:03000035               supraglacial lake
# 6   FOODON:03500021                             NaN
# 7     MICRO:0001773                             NaN
# 8     ENVO:00001999               marine water body
# 9       NCIT:C93162                             NaN
# 10        NCIT:C449                             NaN
# 11      NCIT:C95940                             NaN
# 12      NCIT:C83759                             NaN
# 13     NCIT:C178572                             NaN
# 14      NCIT:C54031                             NaN
# 15      NCIT:C48660                             NaN
# 16     OMIT:0011906                             NaN
# 17     OMIT:0020780                             NaN
# 18     OMIT:0056524                             NaN
# 19    ENVO:01001190                   brown sea ice
# 20    ENVO:00002150               coastal sea water
# 21    ENVO:00002011                     fresh water
# 22    ENVO:00002149                       sea water
# 23    ENVO:00002149                       sea water
#
#                              label ontology_prefix  include  \
# 0                               ci             CCO    False
# 1                               NA          CO_357    False
# 2                              MAT            EDAM    False
# 3   deep chlorophyll maximum layer            ENVO    False
# 4               oligotrophic water            ENVO    False
# 5                supraglacial lake            ENVO    False
# 6                    polypropylene         GENEPIO    False
# 7                filtered seawater           MICRO    False
# 8                marine water body           MICRO    False
# 9                         Aluminum            NCIT    False
# 10                             DNA            NCIT    False
# 11                     Genomic DNA            NCIT    False
# 12       High Density Polyethylene            NCIT    False
# 13                      Buffer TCL            NCIT    False
# 14                         Missing            NCIT    False
# 15                  Not Applicable            NCIT    False
# 16                        Plankton            OMIT    False
# 17                    Polyethylene            OMIT    False
# 18                              VV            OMIT    False
# 19                   brown sea ice            ENVO     True
# 20               coastal sea water            ENVO     True
# 21                     fresh water            ENVO     True
# 22                       sea water            ENVO     True
# 23                       sea water            ENVO     True
#
#    ols_curation_notes              scope        type  \
# 0                                  label       label
# 1                                  label       label
# 2                                  label       label
# 3                                  label       label
# 4                                  label       label
# 5                                  label       label
# 6                                  label       label
# 7                                  label       label
# 8                                synonym     synonym
# 9                                  label       label
# 10                                 label       label
# 11                                 label       label
# 12                               synonym     synonym
# 13                               synonym     synonym
# 14                                 label       label
# 15                                 label       label
# 16                                 label       label
# 17                                 label       label
# 18                                 label       label
# 19                               synonym     synonym
# 20                     has_broad_synonym  annotation
# 21                               synonym     synonym
# 22                               synonym     synonym
# 23                               synonym     synonym
#
#                                                iri ontology_name  \
# 0            http://identifiers.org/ncbigene/43767           cco
# 1   http://www.cropontology.org/rdf/CO_357:2100001        co_357
# 2              http://edamontology.org/format_3626          edam
# 3     http://purl.obolibrary.org/obo/ENVO_01000326          envo
# 4     http://purl.obolibrary.org/obo/ENVO_00002223          envo
# 5     http://purl.obolibrary.org/obo/ENVO_03000035          envo
# 6   http://purl.obolibrary.org/obo/FOODON_03500021       genepio
# 7     http://purl.obolibrary.org/obo/MICRO_0001773         micro
# 8     http://purl.obolibrary.org/obo/ENVO_00001999         micro
# 9       http://purl.obolibrary.org/obo/NCIT_C93162          ncit
# 10        http://purl.obolibrary.org/obo/NCIT_C449          ncit
# 11      http://purl.obolibrary.org/obo/NCIT_C95940          ncit
# 12      http://purl.obolibrary.org/obo/NCIT_C83759          ncit
# 13     http://purl.obolibrary.org/obo/NCIT_C178572          ncit
# 14      http://purl.obolibrary.org/obo/NCIT_C54031          ncit
# 15      http://purl.obolibrary.org/obo/NCIT_C48660          ncit
# 16     http://purl.obolibrary.org/obo/OMIT_0011906          omit
# 17     http://purl.obolibrary.org/obo/OMIT_0020780          omit
# 18     http://purl.obolibrary.org/obo/OMIT_0056524          omit
# 19    http://purl.obolibrary.org/obo/ENVO_01001190          envo
# 20    http://purl.obolibrary.org/obo/ENVO_00002150          envo
# 21    http://purl.obolibrary.org/obo/ENVO_00002011          envo
# 22    http://purl.obolibrary.org/obo/ENVO_00002149          envo
# 23    http://purl.obolibrary.org/obo/ENVO_00002149          envo
#
#     string_dist_rank  string_dist  search_rank
# 0                  1        0.000            1
# 1                  1        0.000            1
# 2                  1        0.000            1
# 3                  1        0.109            1
# 4                  1        0.123            1
# 5                  1        0.134            1
# 6                  1        0.000            1
# 7                  1        0.132            1
# 8                  1        0.144            3
# 9                  1        0.000            1
# 10                 1        0.000            1
# 11                 1        0.000            1
# 12                 1        0.000            1
# 13                 1        0.144            2
# 14                 1        0.000            1
# 15                 1        0.000            1
# 16                 1        0.000            1
# 17                 1        0.000            1
# 18                 1        0.000            1
# 19                 1        0.000            1
# 20                 1        0.000            1
# 21                 1        0.000            1
# 22                 1        0.000            1
# 23                 1        0.000            1

# %% [markdown]
# ## print mapped column and scoping

# %%
bas_rowcount = len(best_and_salvage.index)

sca  = [ scoping_col ]          * bas_rowcount
sva  = [ scoping_value ]        * bas_rowcount
ctma = [ biosample_col_to_map ] * bas_rowcount

scs  = pd.Series(sca)
svs  = pd.Series(sva)
ctms = pd.Series(ctma)

constants = pd.concat([scs, svs, ctms], axis=1)

constants.columns = ['scoping_col','scoping_value','biosample_col_to_map']

# temp = pd.concat([constants, best_and_salvage], axis=1, ignore_index=True)

best_and_salvage = pd.concat([constants, best_and_salvage], axis=1)

best_and_salvage
# Out:
#                              scoping_col scoping_value biosample_col_to_map  \
# 0   env_package_normalization.EnvPackage         water           env_medium
# 1   env_package_normalization.EnvPackage         water           env_medium
# 2   env_package_normalization.EnvPackage         water           env_medium
# 3   env_package_normalization.EnvPackage         water           env_medium
# 4   env_package_normalization.EnvPackage         water           env_medium
# 5   env_package_normalization.EnvPackage         water           env_medium
# 6   env_package_normalization.EnvPackage         water           env_medium
# 7   env_package_normalization.EnvPackage         water           env_medium
# 8   env_package_normalization.EnvPackage         water           env_medium
# 9   env_package_normalization.EnvPackage         water           env_medium
# 10  env_package_normalization.EnvPackage         water           env_medium
# 11  env_package_normalization.EnvPackage         water           env_medium
# 12  env_package_normalization.EnvPackage         water           env_medium
# 13  env_package_normalization.EnvPackage         water           env_medium
# 14  env_package_normalization.EnvPackage         water           env_medium
# 15  env_package_normalization.EnvPackage         water           env_medium
# 16  env_package_normalization.EnvPackage         water           env_medium
# 17  env_package_normalization.EnvPackage         water           env_medium
# 18  env_package_normalization.EnvPackage         water           env_medium
# 19  env_package_normalization.EnvPackage         water           env_medium
# 20  env_package_normalization.EnvPackage         water           env_medium
# 21  env_package_normalization.EnvPackage         water           env_medium
# 22  env_package_normalization.EnvPackage         water           env_medium
# 23  env_package_normalization.EnvPackage         water           env_medium
#
#                 category                           raw  \
# 0                salvage                            ci
# 1                salvage                            na
# 2                salvage                           mat
# 3                salvage      deep chlorophyll maximum
# 4                salvage  sea water oligotrophic water
# 5                salvage       supraglacial lake water
# 6                salvage                 polypropylene
# 7                salvage                filtered water
# 8                salvage                  marine water
# 9                salvage                      aluminum
# 10               salvage                           dna
# 11               salvage                   genomic dna
# 12               salvage                          hdpe
# 13               salvage                  lysis buffer
# 14               salvage                       missing
# 15               salvage                not applicable
# 16               salvage                      plankton
# 17               salvage                  polyethylene
# 18               salvage                            vv
# 19  preferred ontologies      brownish colored sea ice
# 20  preferred ontologies                 coastal water
# 21  preferred ontologies                    freshwater
# 22  preferred ontologies                   ocean water
# 23  preferred ontologies                      seawater
#
#                            query                            name  \
# 0                             ci                              ci
# 1                             na                              NA
# 2                            mat                             MAT
# 3       deep chlorophyll maximum  deep chlorophyll maximum layer
# 4   sea water oligotrophic water              oligotrophic water
# 5        supraglacial lake water               supraglacial lake
# 6                  polypropylene                   polypropylene
# 7                 filtered water               filtered seawater
# 8                   marine water                marine waterbody
# 9                       aluminum                        Aluminum
# 10                           dna                             DNA
# 11                   genomic dna                     Genomic DNA
# 12                          hdpe                            hdpe
# 13                  lysis buffer                tcl lysis buffer
# 14                       missing                         Missing
# 15                not applicable                  Not Applicable
# 16                      plankton                        Plankton
# 17                  polyethylene                    Polyethylene
# 18                            vv                              VV
# 19      brownish colored sea ice        brownish colored sea ice
# 20                 coastal water                   coastal water
# 21                    freshwater                      freshwater
# 22                   ocean water                     ocean water
# 23                      seawater                        seawater
#
#              obo_id                           value  \
# 0               NaN                             NaN
# 1    CO_357:2100001                             NaN
# 2       format:3626                             NaN
# 3     ENVO:01000326  deep chlorophyll maximum layer
# 4     ENVO:00002223              oligotrophic water
# 5     ENVO:03000035               supraglacial lake
# 6   FOODON:03500021                             NaN
# 7     MICRO:0001773                             NaN
# 8     ENVO:00001999               marine water body
# 9       NCIT:C93162                             NaN
# 10        NCIT:C449                             NaN
# 11      NCIT:C95940                             NaN
# 12      NCIT:C83759                             NaN
# 13     NCIT:C178572                             NaN
# 14      NCIT:C54031                             NaN
# 15      NCIT:C48660                             NaN
# 16     OMIT:0011906                             NaN
# 17     OMIT:0020780                             NaN
# 18     OMIT:0056524                             NaN
# 19    ENVO:01001190                   brown sea ice
# 20    ENVO:00002150               coastal sea water
# 21    ENVO:00002011                     fresh water
# 22    ENVO:00002149                       sea water
# 23    ENVO:00002149                       sea water
#
#                              label ontology_prefix  include  \
# 0                               ci             CCO    False
# 1                               NA          CO_357    False
# 2                              MAT            EDAM    False
# 3   deep chlorophyll maximum layer            ENVO    False
# 4               oligotrophic water            ENVO    False
# 5                supraglacial lake            ENVO    False
# 6                    polypropylene         GENEPIO    False
# 7                filtered seawater           MICRO    False
# 8                marine water body           MICRO    False
# 9                         Aluminum            NCIT    False
# 10                             DNA            NCIT    False
# 11                     Genomic DNA            NCIT    False
# 12       High Density Polyethylene            NCIT    False
# 13                      Buffer TCL            NCIT    False
# 14                         Missing            NCIT    False
# 15                  Not Applicable            NCIT    False
# 16                        Plankton            OMIT    False
# 17                    Polyethylene            OMIT    False
# 18                              VV            OMIT    False
# 19                   brown sea ice            ENVO     True
# 20               coastal sea water            ENVO     True
# 21                     fresh water            ENVO     True
# 22                       sea water            ENVO     True
# 23                       sea water            ENVO     True
#
#    ols_curation_notes              scope        type  \
# 0                                  label       label
# 1                                  label       label
# 2                                  label       label
# 3                                  label       label
# 4                                  label       label
# 5                                  label       label
# 6                                  label       label
# 7                                  label       label
# 8                                synonym     synonym
# 9                                  label       label
# 10                                 label       label
# 11                                 label       label
# 12                               synonym     synonym
# 13                               synonym     synonym
# 14                                 label       label
# 15                                 label       label
# 16                                 label       label
# 17                                 label       label
# 18                                 label       label
# 19                               synonym     synonym
# 20                     has_broad_synonym  annotation
# 21                               synonym     synonym
# 22                               synonym     synonym
# 23                               synonym     synonym
#
#                                                iri ontology_name  \
# 0            http://identifiers.org/ncbigene/43767           cco
# 1   http://www.cropontology.org/rdf/CO_357:2100001        co_357
# 2              http://edamontology.org/format_3626          edam
# 3     http://purl.obolibrary.org/obo/ENVO_01000326          envo
# 4     http://purl.obolibrary.org/obo/ENVO_00002223          envo
# 5     http://purl.obolibrary.org/obo/ENVO_03000035          envo
# 6   http://purl.obolibrary.org/obo/FOODON_03500021       genepio
# 7     http://purl.obolibrary.org/obo/MICRO_0001773         micro
# 8     http://purl.obolibrary.org/obo/ENVO_00001999         micro
# 9       http://purl.obolibrary.org/obo/NCIT_C93162          ncit
# 10        http://purl.obolibrary.org/obo/NCIT_C449          ncit
# 11      http://purl.obolibrary.org/obo/NCIT_C95940          ncit
# 12      http://purl.obolibrary.org/obo/NCIT_C83759          ncit
# 13     http://purl.obolibrary.org/obo/NCIT_C178572          ncit
# 14      http://purl.obolibrary.org/obo/NCIT_C54031          ncit
# 15      http://purl.obolibrary.org/obo/NCIT_C48660          ncit
# 16     http://purl.obolibrary.org/obo/OMIT_0011906          omit
# 17     http://purl.obolibrary.org/obo/OMIT_0020780          omit
# 18     http://purl.obolibrary.org/obo/OMIT_0056524          omit
# 19    http://purl.obolibrary.org/obo/ENVO_01001190          envo
# 20    http://purl.obolibrary.org/obo/ENVO_00002150          envo
# 21    http://purl.obolibrary.org/obo/ENVO_00002011          envo
# 22    http://purl.obolibrary.org/obo/ENVO_00002149          envo
# 23    http://purl.obolibrary.org/obo/ENVO_00002149          envo
#
#     string_dist_rank  string_dist  search_rank
# 0                  1        0.000            1
# 1                  1        0.000            1
# 2                  1        0.000            1
# 3                  1        0.109            1
# 4                  1        0.123            1
# 5                  1        0.134            1
# 6                  1        0.000            1
# 7                  1        0.132            1
# 8                  1        0.144            3
# 9                  1        0.000            1
# 10                 1        0.000            1
# 11                 1        0.000            1
# 12                 1        0.000            1
# 13                 1        0.144            2
# 14                 1        0.000            1
# 15                 1        0.000            1
# 16                 1        0.000            1
# 17                 1        0.000            1
# 18                 1        0.000            1
# 19                 1        0.000            1
# 20                 1        0.000            1
# 21                 1        0.000            1
# 22                 1        0.000            1
# 23                 1        0.000            1

# %%
best_and_salvage.to_clipboard(index=False)

# %%
raise SystemExit("Don't skip reviewing and saving!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Don't skip reviewing and saving!
# /Users/MAM/Documents/gitrepos/biosample-analysis/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3425: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Do some review in a spreadsheet application!
# Specifically, columns `include` and `ols_curation_notes`
#
# Then copy back onto clipboard and resume below
#
# **Add counts back in to motivate manual lookups if necessary**
#
# ----

# %%
curated = pd.read_clipboard()
curated
# Out:
#                              scoping_col scoping_value biosample_col_to_map  \
# 0   env_package_normalization.EnvPackage         water           env_medium
# 1   env_package_normalization.EnvPackage         water           env_medium
# 2   env_package_normalization.EnvPackage         water           env_medium
# 3   env_package_normalization.EnvPackage         water           env_medium
# 4   env_package_normalization.EnvPackage         water           env_medium
# 5   env_package_normalization.EnvPackage         water           env_medium
# 6   env_package_normalization.EnvPackage         water           env_medium
# 7   env_package_normalization.EnvPackage         water           env_medium
# 8   env_package_normalization.EnvPackage         water           env_medium
# 9   env_package_normalization.EnvPackage         water           env_medium
# 10  env_package_normalization.EnvPackage         water           env_medium
# 11  env_package_normalization.EnvPackage         water           env_medium
# 12  env_package_normalization.EnvPackage         water           env_medium
# 13  env_package_normalization.EnvPackage         water           env_medium
# 14  env_package_normalization.EnvPackage         water           env_medium
# 15  env_package_normalization.EnvPackage         water           env_medium
# 16  env_package_normalization.EnvPackage         water           env_medium
# 17  env_package_normalization.EnvPackage         water           env_medium
# 18  env_package_normalization.EnvPackage         water           env_medium
# 19  env_package_normalization.EnvPackage         water           env_medium
# 20  env_package_normalization.EnvPackage         water           env_medium
# 21  env_package_normalization.EnvPackage         water           env_medium
# 22  env_package_normalization.EnvPackage         water           env_medium
# 23  env_package_normalization.EnvPackage         water           env_medium
#
#                 category                           raw  \
# 0                salvage  sea water oligotrophic water
# 1                salvage      deep chlorophyll maximum
# 2                salvage       supraglacial lake water
# 3                salvage                 polypropylene
# 4                salvage                  marine water
# 5                salvage                            ci
# 6                salvage                            na
# 7                salvage                           mat
# 8                salvage                filtered water
# 9                salvage                      aluminum
# 10               salvage                           dna
# 11               salvage                   genomic dna
# 12               salvage                          hdpe
# 13               salvage                  lysis buffer
# 14               salvage                       missing
# 15               salvage                not applicable
# 16               salvage                      plankton
# 17               salvage                  polyethylene
# 18               salvage                            vv
# 19  preferred ontologies      brownish colored sea ice
# 20  preferred ontologies                 coastal water
# 21  preferred ontologies                    freshwater
# 22  preferred ontologies                   ocean water
# 23  preferred ontologies                      seawater
#
#                            query                            name  \
# 0   sea water oligotrophic water              oligotrophic water
# 1       deep chlorophyll maximum  deep chlorophyll maximum layer
# 2        supraglacial lake water               supraglacial lake
# 3                  polypropylene                   polypropylene
# 4                   marine water                marine waterbody
# 5                             ci                              ci
# 6                             na                             NaN
# 7                            mat                             MAT
# 8                 filtered water               filtered seawater
# 9                       aluminum                        Aluminum
# 10                           dna                             DNA
# 11                   genomic dna                     Genomic DNA
# 12                          hdpe                            hdpe
# 13                  lysis buffer                tcl lysis buffer
# 14                       missing                         Missing
# 15                not applicable                  Not Applicable
# 16                      plankton                        Plankton
# 17                  polyethylene                    Polyethylene
# 18                            vv                              VV
# 19      brownish colored sea ice        brownish colored sea ice
# 20                 coastal water                   coastal water
# 21                    freshwater                      freshwater
# 22                   ocean water                     ocean water
# 23                      seawater                        seawater
#
#              obo_id                           value  \
# 0     ENVO:00002223              oligotrophic water
# 1     ENVO:01000326  deep chlorophyll maximum layer
# 2     ENVO:03000035               supraglacial lake
# 3   FOODON:03500021                             NaN
# 4     ENVO:00001999               marine water body
# 5               NaN                             NaN
# 6    CO_357:2100001                             NaN
# 7       format:3626                             NaN
# 8     MICRO:0001773                             NaN
# 9       NCIT:C93162                             NaN
# 10        NCIT:C449                             NaN
# 11      NCIT:C95940                             NaN
# 12      NCIT:C83759                             NaN
# 13     NCIT:C178572                             NaN
# 14      NCIT:C54031                             NaN
# 15      NCIT:C48660                             NaN
# 16     OMIT:0011906                             NaN
# 17     OMIT:0020780                             NaN
# 18     OMIT:0056524                             NaN
# 19    ENVO:01001190                   brown sea ice
# 20    ENVO:00002150               coastal sea water
# 21    ENVO:00002011                     fresh water
# 22    ENVO:00002149                       sea water
# 23    ENVO:00002149                       sea water
#
#                              label ontology_prefix  include  \
# 0               oligotrophic water            ENVO    False
# 1   deep chlorophyll maximum layer            ENVO     True
# 2                supraglacial lake            ENVO     True
# 3                    polypropylene         GENEPIO     True
# 4                marine water body           MICRO     True
# 5                               ci             CCO    False
# 6                              NaN          CO_357    False
# 7                              MAT            EDAM    False
# 8                filtered seawater           MICRO    False
# 9                         Aluminum            NCIT    False
# 10                             DNA            NCIT    False
# 11                     Genomic DNA            NCIT    False
# 12       High Density Polyethylene            NCIT    False
# 13                      Buffer TCL            NCIT    False
# 14                         Missing            NCIT    False
# 15                  Not Applicable            NCIT    False
# 16                        Plankton            OMIT    False
# 17                    Polyethylene            OMIT    False
# 18                              VV            OMIT    False
# 19                   brown sea ice            ENVO     True
# 20               coastal sea water            ENVO     True
# 21                     fresh water            ENVO     True
# 22                       sea water            ENVO     True
# 23                       sea water            ENVO     True
#
#     ols_curation_notes              scope        type  \
# 0                  NaN              label       label
# 1                  NaN              label       label
# 2                  NaN              label       label
# 3                  NaN              label       label
# 4                  NaN            synonym     synonym
# 5                  NaN              label       label
# 6                  NaN              label       label
# 7                  NaN              label       label
# 8                  NaN              label       label
# 9                  NaN              label       label
# 10                 NaN              label       label
# 11                 NaN              label       label
# 12                 NaN            synonym     synonym
# 13                 NaN            synonym     synonym
# 14                 NaN              label       label
# 15                 NaN              label       label
# 16                 NaN              label       label
# 17                 NaN              label       label
# 18                 NaN              label       label
# 19                 NaN            synonym     synonym
# 20                 NaN  has_broad_synonym  annotation
# 21                 NaN            synonym     synonym
# 22                 NaN            synonym     synonym
# 23                 NaN            synonym     synonym
#
#                                                iri ontology_name  \
# 0     http://purl.obolibrary.org/obo/ENVO_00002223          envo
# 1     http://purl.obolibrary.org/obo/ENVO_01000326          envo
# 2     http://purl.obolibrary.org/obo/ENVO_03000035          envo
# 3   http://purl.obolibrary.org/obo/FOODON_03500021       genepio
# 4     http://purl.obolibrary.org/obo/ENVO_00001999         micro
# 5            http://identifiers.org/ncbigene/43767           cco
# 6   http://www.cropontology.org/rdf/CO_357:2100001        co_357
# 7              http://edamontology.org/format_3626          edam
# 8     http://purl.obolibrary.org/obo/MICRO_0001773         micro
# 9       http://purl.obolibrary.org/obo/NCIT_C93162          ncit
# 10        http://purl.obolibrary.org/obo/NCIT_C449          ncit
# 11      http://purl.obolibrary.org/obo/NCIT_C95940          ncit
# 12      http://purl.obolibrary.org/obo/NCIT_C83759          ncit
# 13     http://purl.obolibrary.org/obo/NCIT_C178572          ncit
# 14      http://purl.obolibrary.org/obo/NCIT_C54031          ncit
# 15      http://purl.obolibrary.org/obo/NCIT_C48660          ncit
# 16     http://purl.obolibrary.org/obo/OMIT_0011906          omit
# 17     http://purl.obolibrary.org/obo/OMIT_0020780          omit
# 18     http://purl.obolibrary.org/obo/OMIT_0056524          omit
# 19    http://purl.obolibrary.org/obo/ENVO_01001190          envo
# 20    http://purl.obolibrary.org/obo/ENVO_00002150          envo
# 21    http://purl.obolibrary.org/obo/ENVO_00002011          envo
# 22    http://purl.obolibrary.org/obo/ENVO_00002149          envo
# 23    http://purl.obolibrary.org/obo/ENVO_00002149          envo
#
#     string_dist_rank  string_dist  search_rank
# 0                  1        0.123            1
# 1                  1        0.109            1
# 2                  1        0.134            1
# 3                  1        0.000            1
# 4                  1        0.144            3
# 5                  1        0.000            1
# 6                  1        0.000            1
# 7                  1        0.000            1
# 8                  1        0.132            1
# 9                  1        0.000            1
# 10                 1        0.000            1
# 11                 1        0.000            1
# 12                 1        0.000            1
# 13                 1        0.144            2
# 14                 1        0.000            1
# 15                 1        0.000            1
# 16                 1        0.000            1
# 17                 1        0.000            1
# 18                 1        0.000            1
# 19                 1        0.000            1
# 20                 1        0.000            1
# 21                 1        0.000            1
# 22                 1        0.000            1
# 23                 1        0.000            1

# %% [markdown]
# ## Filter on `include`

# %%
flag = curated["include"]
curated = curated.loc[flag]

curated.columns = "ols_" + curated.columns
# curated.to_sql("curated", biosample_cnx, if_exists="replace", index=False)

curated
# Out:
#                          ols_scoping_col ols_scoping_value  \
# 1   env_package_normalization.EnvPackage             water
# 2   env_package_normalization.EnvPackage             water
# 3   env_package_normalization.EnvPackage             water
# 4   env_package_normalization.EnvPackage             water
# 19  env_package_normalization.EnvPackage             water
# 20  env_package_normalization.EnvPackage             water
# 21  env_package_normalization.EnvPackage             water
# 22  env_package_normalization.EnvPackage             water
# 23  env_package_normalization.EnvPackage             water
#
#    ols_biosample_col_to_map          ols_category                   ols_raw  \
# 1                env_medium               salvage  deep chlorophyll maximum
# 2                env_medium               salvage   supraglacial lake water
# 3                env_medium               salvage             polypropylene
# 4                env_medium               salvage              marine water
# 19               env_medium  preferred ontologies  brownish colored sea ice
# 20               env_medium  preferred ontologies             coastal water
# 21               env_medium  preferred ontologies                freshwater
# 22               env_medium  preferred ontologies               ocean water
# 23               env_medium  preferred ontologies                  seawater
#
#                    ols_query                        ols_name       ols_obo_id  \
# 1   deep chlorophyll maximum  deep chlorophyll maximum layer    ENVO:01000326
# 2    supraglacial lake water               supraglacial lake    ENVO:03000035
# 3              polypropylene                   polypropylene  FOODON:03500021
# 4               marine water                marine waterbody    ENVO:00001999
# 19  brownish colored sea ice        brownish colored sea ice    ENVO:01001190
# 20             coastal water                   coastal water    ENVO:00002150
# 21                freshwater                      freshwater    ENVO:00002011
# 22               ocean water                     ocean water    ENVO:00002149
# 23                  seawater                        seawater    ENVO:00002149
#
#                          ols_value                       ols_label  \
# 1   deep chlorophyll maximum layer  deep chlorophyll maximum layer
# 2                supraglacial lake               supraglacial lake
# 3                              NaN                   polypropylene
# 4                marine water body               marine water body
# 19                   brown sea ice                   brown sea ice
# 20               coastal sea water               coastal sea water
# 21                     fresh water                     fresh water
# 22                       sea water                       sea water
# 23                       sea water                       sea water
#
#    ols_ontology_prefix  ols_include  ols_ols_curation_notes  \
# 1                 ENVO         True                     NaN
# 2                 ENVO         True                     NaN
# 3              GENEPIO         True                     NaN
# 4                MICRO         True                     NaN
# 19                ENVO         True                     NaN
# 20                ENVO         True                     NaN
# 21                ENVO         True                     NaN
# 22                ENVO         True                     NaN
# 23                ENVO         True                     NaN
#
#             ols_scope    ols_type  \
# 1               label       label
# 2               label       label
# 3               label       label
# 4             synonym     synonym
# 19            synonym     synonym
# 20  has_broad_synonym  annotation
# 21            synonym     synonym
# 22            synonym     synonym
# 23            synonym     synonym
#
#                                            ols_iri ols_ontology_name  \
# 1     http://purl.obolibrary.org/obo/ENVO_01000326              envo
# 2     http://purl.obolibrary.org/obo/ENVO_03000035              envo
# 3   http://purl.obolibrary.org/obo/FOODON_03500021           genepio
# 4     http://purl.obolibrary.org/obo/ENVO_00001999             micro
# 19    http://purl.obolibrary.org/obo/ENVO_01001190              envo
# 20    http://purl.obolibrary.org/obo/ENVO_00002150              envo
# 21    http://purl.obolibrary.org/obo/ENVO_00002011              envo
# 22    http://purl.obolibrary.org/obo/ENVO_00002149              envo
# 23    http://purl.obolibrary.org/obo/ENVO_00002149              envo
#
#     ols_string_dist_rank  ols_string_dist  ols_search_rank
# 1                      1            0.109                1
# 2                      1            0.134                1
# 3                      1            0.000                1
# 4                      1            0.144                3
# 19                     1            0.000                1
# 20                     1            0.000                1
# 21                     1            0.000                1
# 22                     1            0.000                1
# 23                     1            0.000                1

# %%
merge_search_merged = mapping_candidates.merge(
    curated, how="outer", left_on="remaining_tidied", right_on="ols_raw"
)

# %%
# merge_search_merged.to_csv("merge_search_merged.csv")

# %%
flag = (
    ~merge_search_merged["id_or_lab_ok"]
    & ~merge_search_merged["ols_obo_id"].eq("")
    & ~merge_search_merged["ols_obo_id"].isna()
)

replacement = merge_search_merged.loc[flag, "ols_obo_id"]

merge_search_merged.loc[flag, "consensus_id"] = replacement

replacement = merge_search_merged.loc[flag, "ols_label"]

merge_search_merged.loc[flag, "consensus_lab"] = replacement

replacement = (
    merge_search_merged.loc[flag, "consensus_lab"]
    + " ["
    + merge_search_merged.loc[flag, "consensus_id"]
    + "]"
)

merge_search_merged.loc[flag, "assembled_consensus"] = replacement

merge_search_merged
# Out:
#                                             env_medium  count  \
# 0                                          fresh water   5847
# 1                          fresh water [ENVO:00002011]     42
# 2                                                water   1913
# 3                                                Water    474
# 4                                      missing|||water      2
# ..                                                 ...    ...
# 208  seawater/brine transition zone lower halocline...      1
# 209  seawater/brine transition zone lower halocline...      1
# 210  seawater/brine transition zone upper halocline...      1
# 211  seawater/brine transition zone upper halocline...      1
# 212                      water from hydrothermal plume      1
#
#                                               repeated  \
# 0                                          fresh water
# 1                          fresh water [ENVO:00002011]
# 2                                                water
# 3                                                Water
# 4                                      missing|||water
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                               splitted  part_count  seq  \
# 0                                          fresh water           1    1
# 1                          fresh water [ENVO:00002011]           1    1
# 2                                                water           1    1
# 3                                                Water           1    1
# 4                                                water           2    2
# ..                                                 ...         ...  ...
# 208  seawater/brine transition zone lower halocline...           1    1
# 209  seawater/brine transition zone lower halocline...           1    1
# 210  seawater/brine transition zone upper halocline...           1    1
# 211  seawater/brine transition zone upper halocline...           1    1
# 212                      water from hydrothermal plume           1    1
#
#                                              term_tidy  \
# 0                                          fresh water
# 1                          fresh water [ENVO:00002011]
# 2                                                water
# 3                                                Water
# 4                                                water
# ..                                                 ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                                 string        extract  \
# 0                                          fresh water
# 1                          fresh water [ENVO:00002011]  ENVO:00002011
# 2                                                water
# 3                                                Water
# 4                                                water
# ..                                                 ...            ...
# 208  seawater/brine transition zone lower halocline...
# 209  seawater/brine transition zone lower halocline...
# 210  seawater/brine transition zone upper halocline...
# 211  seawater/brine transition zone upper halocline...
# 212                      water from hydrothermal plume
#
#                                       remaining_string  ...  \
# 0                                          fresh water  ...
# 1                                         fresh water   ...
# 2                                                water  ...
# 3                                                Water  ...
# 4                                                water  ...
# ..                                                 ...  ...
# 208  seawater/brine transition zone lower halocline...  ...
# 209  seawater/brine transition zone lower halocline...  ...
# 210  seawater/brine transition zone upper halocline...  ...
# 211  seawater/brine transition zone upper halocline...  ...
# 212                      water from hydrothermal plume  ...
#
#     ols_ontology_prefix ols_include ols_ols_curation_notes  ols_scope  \
# 0                   NaN         NaN                    NaN        NaN
# 1                   NaN         NaN                    NaN        NaN
# 2                   NaN         NaN                    NaN        NaN
# 3                   NaN         NaN                    NaN        NaN
# 4                   NaN         NaN                    NaN        NaN
# ..                  ...         ...                    ...        ...
# 208                 NaN         NaN                    NaN        NaN
# 209                 NaN         NaN                    NaN        NaN
# 210                 NaN         NaN                    NaN        NaN
# 211                 NaN         NaN                    NaN        NaN
# 212                 NaN         NaN                    NaN        NaN
#
#     ols_type ols_iri ols_ontology_name  ols_string_dist_rank ols_string_dist  \
# 0        NaN     NaN               NaN                   NaN             NaN
# 1        NaN     NaN               NaN                   NaN             NaN
# 2        NaN     NaN               NaN                   NaN             NaN
# 3        NaN     NaN               NaN                   NaN             NaN
# 4        NaN     NaN               NaN                   NaN             NaN
# ..       ...     ...               ...                   ...             ...
# 208      NaN     NaN               NaN                   NaN             NaN
# 209      NaN     NaN               NaN                   NaN             NaN
# 210      NaN     NaN               NaN                   NaN             NaN
# 211      NaN     NaN               NaN                   NaN             NaN
# 212      NaN     NaN               NaN                   NaN             NaN
#
#     ols_search_rank
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 208             NaN
# 209             NaN
# 210             NaN
# 211             NaN
# 212             NaN
#
# [213 rows x 42 columns]

# %%
# merge_search_merged.to_sql(
#     "merge_search_merged", biosample_cnx, if_exists="replace", index=False
# )

# %%
summary = merge_search_merged[[biosample_col_to_map, "count", "assembled_consensus"]]
summary = summary.sort_values("count", ascending=False)

# %%
# could still make better use of SSSOM columns

frame_for_sssom = merge_search_merged

na_flag = frame_for_sssom["splitted"].isna()
frame_for_sssom = frame_for_sssom[~na_flag]

na_flag = frame_for_sssom["consensus_id"].isna()
frame_for_sssom = frame_for_sssom[~na_flag]

raw_queries = list(frame_for_sssom["splitted"])
urlencodeds = list(map(urllib.parse.quote, raw_queries))
urlencodeds = [sssom_subject_prefix + ":" + item for item in urlencodeds]

results_rows = len(frame_for_sssom.index)
iso8601_stamp = datetime.now().replace(microsecond=0).isoformat()

sssom_frame = {
    "subject_category": [biosample_col_to_map] * results_rows,
    "subject_label": frame_for_sssom["splitted"],
    "predicate_id": ["skos:relatedMatch"] * results_rows,
    "object_id": frame_for_sssom["consensus_id"],
    "object_label": frame_for_sssom["consensus_lab"],
    "match_type": ["Lexical"] * results_rows,
    "creator_id": ["https://github.com/turbomam/scoped-mapping"] * results_rows,
    #     "mapping_tool": ["https://www.ebi.ac.uk/ols/docs/api"] * results_rows,
    "mapping_date": [iso8601_stamp] * results_rows,
    #     "confidence": 1 - frame_for_sssom["string_dist"],
    "subject_id": urlencodeds,
}

sssom_frame = pd.DataFrame(sssom_frame)

sssom_frame.to_csv(sssom_file, sep=ols_review_seperator, index=False)

# %% [markdown]
# ## Join together pipe-delimited _generic_ mappings
# _Any other constraints? If part_count is > 1, do we need to check for empty or null (generic), repeated or splitted?_

# %%
multi_part_flag = merge_search_merged["part_count"] > 1
multi_part_flag.value_counts()
# Out:
# False    207
# True       6
# Name: part_count, dtype: int64

# %%
multi_part_frame = merge_search_merged.loc[multi_part_flag]

# %%
multi_part_frame = multi_part_frame[
    [
        biosample_col_to_map,
        "count",
        "repeated",
        "splitted",
        "part_count",
        "seq",
        "consensus_id",
        "consensus_lab",
    ]
]

multi_part_frame = multi_part_frame.sort_values(
    [biosample_col_to_map, "seq"], ascending=(True, True)
)

# multi_part_frame

# %%
# remove any row whose biosample_col_to_map has any NaN consensus_ids
# deep-sea sediment biome from ENVO:01000030|||deep-sea sediment biome

bad_flag = multi_part_frame['consensus_id'].isna()
print(bad_flag)
bad_c2m = multi_part_frame[biosample_col_to_map][bad_flag]
print(bad_c2m)
keep_flag = ~ multi_part_frame[biosample_col_to_map].isin(bad_c2m)
print(keep_flag)
multi_part_frame = multi_part_frame[keep_flag]
multi_part_frame
# Out:
# 43     False
# 10     False
# 161     True
# 4      False
# 79     False
# 8      False
# Name: consensus_id, dtype: bool
# 161    missing|||water
# Name: env_medium, dtype: object
# 43      True
# 10      True
# 161    False
# 4      False
# 79      True
# 8       True
# Name: env_medium, dtype: bool
#                                            env_medium  count  \
# 43  Coastal sea water [ENVO:00002150]|||sea water ...      7
# 10  Coastal sea water [ENVO:00002150]|||sea water ...      7
# 79  oligotrophic water [ENVO:00002223]|||sea water...     34
# 8   oligotrophic water [ENVO:00002223]|||sea water...     34
#
#                                              repeated  \
# 43  Coastal sea water [ENVO:00002150]|||sea water ...
# 10  Coastal sea water [ENVO:00002150]|||sea water ...
# 79  oligotrophic water [ENVO:00002223]|||sea water...
# 8   oligotrophic water [ENVO:00002223]|||sea water...
#
#                               splitted  part_count  seq   consensus_id  \
# 43   Coastal sea water [ENVO:00002150]           2    1  ENVO:00002150
# 10           sea water [ENVO:00002149]           2    2  ENVO:00002149
# 79  oligotrophic water [ENVO:00002223]           2    1  ENVO:00002223
# 8            sea water [ENVO:00002149]           2    2  ENVO:00002149
#
#          consensus_lab
# 43   coastal sea water
# 10           sea water
# 79  oligotrophic water
# 8            sea water

# %%
part_count = multi_part_frame.groupby([biosample_col_to_map], sort=False)[
    "part_count"
].max()
part_count.value_counts()
# Out:
# 2    2
# Name: part_count, dtype: int64

# %%
seq_max = multi_part_frame.groupby([biosample_col_to_map], sort=False)["seq"].max()
# seq_max

# %%
parts_check = pd.DataFrame(dict(part_count=part_count, seq_max=seq_max)).reset_index()
# parts_check

# %%
all_parts_flag = parts_check["seq_max"] == parts_check["part_count"]
# all_parts_flag

# %%
generic_with_all_parts = parts_check.loc[all_parts_flag, biosample_col_to_map]
# generic_with_all_parts

# %%
all_parts_flag = multi_part_frame[biosample_col_to_map].isin(list(generic_with_all_parts))
all_parts_frame = multi_part_frame.loc[all_parts_flag]
# all_parts_frame

# %%
unique_pipesep_ebs = list(set(list(all_parts_frame[biosample_col_to_map])))
unique_pipesep_ebs.sort()
# print(unique_pipesep_ebs)
repipe_dict_list = []
for one_pipesep in unique_pipesep_ebs:
    flag = all_parts_frame[biosample_col_to_map] == one_pipesep
    temp_frame = all_parts_frame.loc[flag]
#     print(temp_frame)
    ids_list = list(temp_frame["consensus_id"])
    lab_list = list(temp_frame["consensus_lab"])
#     print(ids_list)
#     print(lab_list)
    ids_repipe = rejoin_delim.join(ids_list)
    lab_repipe = rejoin_delim.join(lab_list)

    repipe_dict = {
        biosample_col_to_map: one_pipesep,
        "consensus_id": ids_repipe,
        "consensus_lab": lab_repipe,
    }
    repipe_dict_list.append(repipe_dict)
repipe_frame = pd.DataFrame(repipe_dict_list)
repipe_frame
# Out:
#                                           env_medium  \
# 0  Coastal sea water [ENVO:00002150]|||sea water ...
# 1  oligotrophic water [ENVO:00002223]|||sea water...
#
#                   consensus_id                 consensus_lab
# 0  ENVO:00002150|ENVO:00002149   coastal sea water|sea water
# 1  ENVO:00002223|ENVO:00002149  oligotrophic water|sea water

# %%
sssom_min_cols = sssom_frame[["subject_label", "object_id", "object_label"]]

sssom_min_cols.columns = [biosample_col_to_map, "consensus_id", "consensus_lab"]

# %%
repipe_rows = len(repipe_frame.index)
if repipe_rows > 0:
    direct_and_repipe = pd.concat([sssom_min_cols, repipe_frame])
else:
    direct_and_repipe = sssom_min_cols

# %%
# this is a staging area for builing the repair tables
# same (?) stuff goes into SSSOM files?
direct_and_repipe.to_sql(
    "repair_staging", biosample_cnx, if_exists="replace", index=False
)

# %% [markdown]
# ## refactor this even more?

# %%
q = (
    """
select
	b.id, b."""
    + biosample_col_to_map
    + """,
	rs.consensus_id ,
	rs.consensus_lab
from
	repair_staging rs
left join biosample b on
	b."""
    + biosample_col_to_map
    + """ = rs."""
    + biosample_col_to_map
    + """
inner join biosample_sample_taxon_summary stic on
	b.taxonomy_id = stic.biosample_taxid
join env_package_normalization on
	b.env_package = env_package_normalization.env_package
where """
    + scoping_col
    + " = '"
    + scoping_value
    + "'"
)

[per_biosample_scoped_mapping_results, query_duration] = scoped_mapping.timed_query(
    q, biosample_cnx, print_timing=True
)

per_biosample_scoped_mapping_results.columns = ['id','raw','consensus_id','consensus_lab']

# per_biosample_scoped_mapping_results
# Out:
# 2021-07-07 08:11:44.027327
# 2021-07-07 08:11:44.442829
# 0:00:00.415502

# %%
per_biosample_scoped_mapping_results["biosample_col_to_map"] = biosample_col_to_map
per_biosample_scoped_mapping_results["scoping_col"] = scoping_col
per_biosample_scoped_mapping_results["scoping_value"] = scoping_value

# table_name = "repaired_" + biosample_col_to_map

# per_biosample_scoped_mapping_results = per_biosample_scoped_mapping_results.drop(biosample_col_to_map, 1)

per_biosample_scoped_mapping_results = per_biosample_scoped_mapping_results[['id', 'scoping_col', 'scoping_value', 
                                                                             'biosample_col_to_map', 'raw',
                                                                             'consensus_id', 'consensus_lab']]

# per_biosample_scoped_mapping_results

# %%
per_biosample_scoped_mapping_results.to_sql(
    "repaired_long", biosample_cnx, if_exists="append", index=False
)
